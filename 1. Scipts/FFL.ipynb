# %%
##################################################################################################
## -- Libs
##################################################################################################

import pandas as pd
import numpy as np
import neat
import gc

import warnings

# Suppress FutureWarning messages
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
##################################################################################################
## -- Read in Data
##################################################################################################

# Meta Data
meta = pd.read_csv('../2. Data/meta_data.csv')
feature_types_dict = dict(zip(meta['feature'], meta['feature_type']))

apply_stats_features = meta[meta['apply_stats'] == 1]['feature'].tolist()
modelling_valid_features = meta[meta['modelling_valid'] == 1]['feature'].tolist()

# Current Season
data_22_23 = pd.read_csv('../2. Data/22-23 FFL.csv', dtype=feature_types_dict, usecols=modelling_valid_features).drop_duplicates()
data_22_23['name'] = data_22_23['name'].str.replace(' ', '_')
data_22_23['kickoff_time'] = pd.to_datetime(data_22_23['kickoff_time'], format='%Y-%m-%dT%H:%M:%SZ')

print(f'{data_22_23.shape = }')
ALL_PLAYERS_22_23 = data_22_23.name.unique()

# Last Season
data_21_22 = pd.read_csv('../2. Data/21-22 FFL.csv', dtype=feature_types_dict).drop_duplicates()
data_21_22['name'] = data_21_22['name'].str.replace(' ', '_')

print(f'{data_21_22.shape = }')

# Clear 
del modelling_valid_features
gc.collect()
# Out:
# data_22_23.shape = (26505, 16)
# data_21_22.shape = (25447, 36)
# 17

# %%
##################################################################################################
## -- Apply stats to Current Season
##################################################################################################

def create_player_dataframes(data, apply_stats_features):
    """
    Creates individual player DataFrames with missing rows for earlier game weeks,
    calculates rolling averages, and concatenates them into a single DataFrame.

    Args:
        data (pd.DataFrame): Original dataset containing player data.
        apply_stats_features (list): List of features for which rolling averages are calculated.

    Returns:
        pd.DataFrame: Updated DataFrame with player data.
    """

    # Create a list to store individual player DataFrames
    player_dfs = []

    # Loop through each player in the dataset
    for player in data['name'].unique():
        player_data = data[data['name'] == player]
        
        # Sort by game week to ensure the data is in order
        player_data = player_data.sort_values(by=['GW'])

        # Find the earliest game week for the player
        earliest_gw = player_data['GW'].min()
        
        # Create missing rows for earlier game weeks
        if earliest_gw > 1:
            missing_data = pd.DataFrame({
                'name': [player] * (earliest_gw - 1),
                'GW': range(1, earliest_gw),
                'player_available': [False] * (earliest_gw - 1)
            })
            
            # Add in the other columns from data and set them to NaN
            for column in data.columns:
                if column not in missing_data.columns:
                    missing_data[column] = np.nan

            # Set the features specified in apply_stats_features to NaN
            for feature in apply_stats_features:
                missing_data[feature] = np.nan
                    
            updated_player_data = pd.concat([missing_data, player_data]).reset_index(drop=True)
        
            # player_available: True for rows in player_data
            updated_player_data['player_available'] = updated_player_data['player_available'].fillna(True)
        else:
            updated_player_data = player_data
            updated_player_data['player_available'] = True
        
        # Calculate the mean and 3/5 GW rolling average for features where apply_stats=True,
        # but only for the weeks when the player is available
        for feature in apply_stats_features:
            updated_player_data[f'{feature}_mean_upto_GW'] = updated_player_data[feature].where(updated_player_data['player_available']).expanding().mean().round(2)
            updated_player_data[f'{feature}_rolling_3GW'] = updated_player_data[feature].where(updated_player_data['player_available']).rolling(window=3).mean().round(2)
            updated_player_data[f'{feature}_rolling_5GW'] = updated_player_data[feature].where(updated_player_data['player_available']).rolling(window=5).mean().round(2)

        player_dfs.append(updated_player_data)

    # Concatenate all player DataFrames into a single DataFrame
    data_updated = pd.concat(player_dfs, ignore_index=True)

    return data_updated


data_22_23_updated = create_player_dataframes(data_22_23, apply_stats_features)

print(f'{data_22_23_updated.shape = }')
# Out:
# data_22_23_updated.shape = (29732, 47)

# %%
##################################################################################################
## -- Create Game Week 0 Data
##################################################################################################

def create_player_gw0_summary(data, ALL_PLAYERS_22_23):
    """
    Creates a summary of player values for the 2021-2022 season and prepares the dataset for Game Week 0.

    Args:
        data (pd.DataFrame): DataFrame containing updated player data for the 2022-2023 season.
        ALL_PLAYERS_22_23 (list): List of player names for the 2022-2023 season.

    Returns:
        pd.DataFrame: Updated DataFrame with player data.
    """
    # Create summary of players' values for the 2021-2022 season
    data_21_22_summary = data.groupby('name').agg(
        last_season_value_mean=('value', 'mean'),
        last_season_value_max=('value', 'max'),
        last_season_value_min=('value', 'min')
    ).reset_index().round(3)

    # Create dataset for Game Week 0
    gw0_player_data = pd.DataFrame({
        'name': ALL_PLAYERS_22_23,
        'GW': 0
    })

    # Join Position, Team, and Player Available from GW1
    gw0_player_data = gw0_player_data.merge(
        data[data['GW'] == 1][['name', 'position', 'team', 'player_available']],
        how='left', on='name'
    )

    # Join Last Season Value Summary Stats
    gw0_player_data = gw0_player_data.merge(
        data_21_22_summary, how='left', on='name'
    )

    # Add in the other columns from data and set them to NaN
    for column in data.columns:
        if column not in gw0_player_data.columns:
            gw0_player_data[column] = np.nan

    # Join GW0 to the main dataset
    data_gw0 = pd.concat([gw0_player_data, data])

    # Create a binary column indicating whether the player is new (last season value is missing)
    data_gw0['new_player'] = data_gw0['last_season_value_mean'].isnull().astype(int)

    return data_gw0

data_22_23_updated_GW0 = create_player_gw0_summary(data_22_23_updated, ALL_PLAYERS_22_23)
print(f'{data_22_23_updated_GW0.shape = }')
# Out:
# data_22_23_updated_GW0.shape = (30510, 51)

# %%
##################################################################################################
## -- One Hot Encode
##################################################################################################

def create_one_hot_encoded_table(data):
    """
    Creates a one-hot encoded DataFrame by converting categorical columns to dummy variables.

    Args:
        data_22_23_updated (pd.DataFrame): DataFrame containing updated player data.
        GW_column_name (str): Name of the game week column (default is 'GW').

    Returns:
        pd.DataFrame: Final DataFrame with one-hot encoded features.
    """

    # Create one-hot encoding for char columns
    one_hot_encoding_list = [data]

    char_cols = [col for col in data.columns if data[col].dtype == object]
    for col in char_cols:
        one_hot = pd.get_dummies(data[col], prefix=col, prefix_sep=':').astype(int)
        one_hot_encoding_list.append(one_hot)

    # Manually create one-hot encoding for GW
    one_hot_gw = pd.get_dummies(data['GW'], prefix='GW', prefix_sep=':').astype(int)
    one_hot_encoding_list.append(one_hot_gw)

    # Create Final  Table
    data_final = pd.concat(one_hot_encoding_list, axis=1)

    return data_final


data_22_23_final = create_one_hot_encoded_table(data_22_23_updated_GW0)
print(f'{data_22_23_final.shape = }')
# Out:
# data_22_23_final.shape = (30510, 891)

# %%
data_22_23_final.name.iloc[0]
# Out:
# 'Nathan_Redmond'

# %%
import sys
# Create a dictionary to store player data
def create_player_dict(data, ALL_PLAYERS_22_23):
    player_dict = {}
    for i, player in enumerate(ALL_PLAYERS_22_23):
        sys.stdout.write(f'\r{player}: {i/len(ALL_PLAYERS_22_23):.2f}%')
        sys.stdout.write('                        ')
        player_data = data[data['name'] == player]
        player_data = player_data.sort_values(by=['GW','kickoff_time'])
        player_data = player_data.groupby('GW').last().reset_index()
        player_dict[player] = {GW: player_data[player_data['GW'] == GW].to_dict(orient='records') for GW in range(39)}

    return player_dict

player_dict = create_player_dict(data_22_23_final, ALL_PLAYERS_22_23)
# Out:
# Ross_Barkley: 0.25%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19840\1173503441.py in ?()
# ---> 15 import sys
#      16 # Create a dictionary to store player data
#      17 def create_player_dict(data, ALL_PLAYERS_22_23):
#      18     player_dict = {}
#
# ~\AppData\Local\Temp\ipykernel_19840\1173503441.py in ?(data, ALL_PLAYERS_22_23)
#       7         sys.stdout.write('                        ')
#       8         player_data = data[data['name'] == player]
#       9         player_data = player_data.sort_values(by=['GW','kickoff_time'])
#      10         player_data = player_data.groupby('GW').last().reset_index()
# ---> 11         player_dict[player] = {GW: player_data[player_data['GW'] == GW].to_dict(orient='records') for GW in range(39)}
#      12
#      13     return player_dict
#
# ~\AppData\Local\Temp\ipykernel_19840\1173503441.py in ?(.0)
# ---> 11 def create_player_dict(data, ALL_PLAYERS_22_23):
#      12     player_dict = {}
#      13     for i, player in enumerate(ALL_PLAYERS_22_23):
#      14         sys.stdout.write(f'\r{player}: {i/len(ALL_PLAYERS_22_23):.2f}%')
#
# c:\Users\jacks\_Coding\Venvs\FFL\lib\site-packages\pandas\util\_decorators.py in ?(*args, **kwargs)
#     329                     msg.format(arguments=_format_argument_list(allow_args)),
#     330                     FutureWarning,
#     331                     stacklevel=find_stack_level(),
#     332                 )
# --> 333             return func(*args, **kwargs)
#
# c:\Users\jacks\_Coding\Venvs\FFL\lib\site-packages\pandas\core\frame.py in ?(self, orient, into, index)
#    2174          defaultdict(<class 'list'>, {'col1': 2, 'col2': 0.75})]
#    2175         """
#    2176         from pandas.core.methods.to_dict import to_dict
#    2177
# -> 2178         return to_dict(self, orient, into=into, index=index)
#
# c:\Users\jacks\_Coding\Venvs\FFL\lib\site-packages\pandas\core\methods\to_dict.py in ?(df, orient, into, index)
#     222                 into_c((k, maybe_box_native(v)) for k, v in row.items()) for row in rows
#     223             ]
#     224         else:
#     225             data = [
# --> 226                 into_c(zip(columns, t)) for t in df.itertuples(index=False, name=None)
#     227             ]
#     228             if box_native_indices:
#     229                 object_dtype_indices_as_set = set(box_native_indices)
#
# c:\Users\jacks\_Coding\Venvs\FFL\lib\site-packages\pandas\core\frame.py in ?(self, index, name)
#    1626             arrays.append(self.index)
#    1627             fields.insert(0, "Index")
#    1628
#    1629         # use integer indexing because of possible duplicate column names
# -> 1630         arrays.extend(self.iloc[:, k] for k in range(len(self.columns)))
#    1631
#    1632         if name is not None:
#    1633             # https://github.com/python/mypy/issues/9046
#
# c:\Users\jacks\_Coding\Venvs\FFL\lib\site-packages\pandas\core\frame.py in ?(.0)
# -> 1630     def itertuples(
#    1631         self, index: bool = True, name: str | None = "Pandas"
#    1632     ) -> Iterable[tuple[Any, ...]]:
#    1633         """
#
# c:\Users\jacks\_Coding\Venvs\FFL\lib\site-packages\pandas\core\indexing.py in ?(self, key)
#    1180             key = tuple(list(x) if is_iterator(x) else x for x in key)
#    1181             key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1182             if self._is_scalar_access(key):
#    1183                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184             return self._getitem_tuple(key)
#    1185         else:
#    1186             # we by definition only have the 0th axis
#    1187             axis = self.axis or 0
#
# c:\Users\jacks\_Coding\Venvs\FFL\lib\site-packages\pandas\core\indexing.py in ?(self, tup)
#    1689     def _getitem_tuple(self, tup: tuple):
#    1690         tup = self._validate_tuple_indexer(tup)
#    1691         with suppress(IndexingError):
# -> 1692             return self._getitem_lowerdim(tup)
#    1693
#    1694         return self._getitem_tuple_same_dim(tup)
#
# c:\Users\jacks\_Coding\Venvs\FFL\lib\site-packages\pandas\core\indexing.py in ?(self, tup)
#    1061         for i, key in enumerate(tup):
#    1062             if is_label_like(key):
#    1063                 # We don't need to check for tuples here because those are
#    1064                 #  caught by the _is_nested_tuple_indexer check above.
# -> 1065                 section = self._getitem_axis(key, axis=i)
#    1066
#    1067                 # We should never have a scalar section here, because
#    1068                 #  _getitem_lowerdim is only called after a check for
#
# c:\Users\jacks\_Coding\Venvs\FFL\lib\site-packages\pandas\core\indexing.py in ?(self, key, axis)
#    1750
#    1751             # validate the location
#    1752             self._validate_integer(key, axis)
#    1753
# -> 1754             return self.obj._ixs(key, axis=axis)
#
# c:\Users\jacks\_Coding\Venvs\FFL\lib\site-packages\pandas\core\frame.py in ?(self, i, axis)
#    4007         else:
#    4008             label = self.columns[i]
#    4009
#    4010             col_mgr = self._mgr.iget(i)
# -> 4011             result = self._box_col_values(col_mgr, i)
#    4012
#    4013             # this is a cached value, mark it so
#    4014             result._set_as_cached(label, self)
#
# KeyboardInterrupt:

# %%
len(ALL_PLAYERS_22_23)
# Out:
# 777

# %%
##################################################################################################
## -- Create Player GW Dict
##################################################################################################

# Create a dictionary to store player data
def create_player_dict(data, ALL_PLAYERS_22_23):
    player_dict = {}
    for player in ALL_PLAYERS_22_23:
        player_data = data[data['name'] == player]
        player_data = player_data.sort_values(by=['GW','kickoff_time'])
        player_data = player_data.groupby('GW').last().reset_index()
        player_dict[player] = {GW: {col: player_data[player_data['GW'] == GW][col].iloc[0] if not player_data[player_data['GW'] == GW].empty else None for col in player_data.columns} for GW in range(39)}
    return player_dict

player_dict2 = create_player_dict(data_22_23_final, ALL_PLAYERS_22_23)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 17
#      13         player_dict[player] = {GW: {col: player_data[player_data['GW'] == GW][col].iloc[0] for col in player_data.columns} for GW in range(39)}
#      15     return player_dict
# ---> 17 player_dict1 = create_player_dict(data_22_23_final, ALL_PLAYERS_22_23)
#
# Cell In[10], line 13, in create_player_dict(data, ALL_PLAYERS_22_23)
#      11     player_data = player_data.groupby('GW').last().reset_index()
#      12     # player_dict[player] = {GW: player_data[player_data['GW'] == GW] for GW in range.(39)}
# ---> 13     player_dict[player] = {GW: {col: player_data[player_data['GW'] == GW][col].iloc[0] for col in player_data.columns} for GW in range(39)}
#      15 return player_dict
#
# Cell In[10], line 13, in <dictcomp>(.0)
#      11     player_data = player_data.groupby('GW').last().reset_index()
#      12     # player_dict[player] = {GW: player_data[player_data['GW'] == GW] for GW in range.(39)}
# ---> 13     player_dict[player] = {GW: {col: player_data[player_data['GW'] == GW][col].iloc[0] for col in player_data.columns} for GW in range(39)}
#      15 return player_dict
#
# Cell In[10], line 13, in <dictcomp>(.0)
#      11     player_data = player_data.groupby('GW').last().reset_index()
#      12     # player_dict[player] = {GW: player_data[player_data['GW'] == GW] for GW in range.(39)}
# ---> 13     player_dict[player] = {GW: {col: player_data[player_data['GW'] == GW][col].iloc[0] for col in player_data.columns} for GW in range(39)}
#      15 return player_dict
#
# File c:\Users\jacks\_Coding\Venvs\FFL\lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\jacks\_Coding\Venvs\FFL\lib\site-packages\pandas\core\indexing.py:1752, in _iLocIndexer._getitem_axis(self, key, axis)
#    1749     raise TypeError("Cannot index by location index with a non-integer key")
#    1751 # validate the location
# -> 1752 self._validate_integer(key, axis)
#    1754 return self.obj._ixs(key, axis=axis)
#
# File c:\Users\jacks\_Coding\Venvs\FFL\lib\site-packages\pandas\core\indexing.py:1685, in _iLocIndexer._validate_integer(self, key, axis)
#    1683 len_axis = len(self.obj._get_axis(axis))
#    1684 if key >= len_axis or key < -len_axis:
# -> 1685     raise IndexError("single positional indexer is out-of-bounds")
#
# IndexError: single positional indexer is out-of-bounds

# %%
def create_player_dict_optimized(data, ALL_PLAYERS_22_23):
    # Sort and group data upfront
    sorted_data = data.sort_values(by=['GW', 'kickoff_time'])
    grouped_data = sorted_data.groupby(['name', 'GW']).last().reset_index()

    # Use a dictionary comprehension to create player_dict
    player_dict = {
        player: {GW: grouped_data[(grouped_data['name'] == player) & (grouped_data['GW'] == GW)] for GW in range(39)} for player in ALL_PLAYERS_22_23
        }

    return player_dict

player_dict2 = create_player_dict_optimized(data_22_23_final, ALL_PLAYERS_22_23)

# %%
player_dict['Weston_McKennie'][22][['kickoff_time'] + [col for col in data_22_23_final.columns if 'influence' in col]]
# Out:
#           kickoff_time  influence  influence_mean_upto_GW  \
# 22 2023-02-08 20:00:00       17.2                     9.8
#
#     influence_rolling_3GW  influence_rolling_5GW
# 22                    NaN                    NaN

# %%
player_dict['Nathan_Redmond'][0].to_dict(orient='records')
# Out:
# [{'GW': 0,
#   'name': 'Nathan_Redmond',
#   'position': 'MID',
#   'team': 'Southampton',
#   'player_available': True,
#   'last_season_value_mean': 53.158,
#   'last_season_value_max': 55.0,
#   'last_season_value_min': 53.0,
#   'xP': nan,
#   'assists': nan,
#   'clean_sheets': nan,
#   'creativity': nan,
#   'fixture': nan,
#   'goals_conceded': nan,
#   'goals_scored': nan,
#   'influence': nan,
#   'kickoff_time': NaT,
#   'red_cards': nan,
#   'value': nan,
#   'yellow_cards': nan,
#   'xP_mean_upto_GW': nan,
#   'xP_rolling_3GW': nan,
#   'xP_rolling_5GW': nan,
#   'assists_mean_upto_GW': nan,
#   'assists_rolling_3GW': nan,
#   'assists_rolling_5GW': nan,
#   'clean_sheets_mean_upto_GW': nan,
#   'clean_sheets_rolling_3GW': nan,
#   'clean_sheets_rolling_5GW': nan,
#   'creativity_mean_upto_GW': nan,
#   'creativity_rolling_3GW': nan,
#   'creativity_rolling_5GW': nan,
#   'goals_conceded_mean_upto_GW': nan,
#   'goals_conceded_rolling_3GW': nan,
#   'goals_conceded_rolling_5GW': nan,
#   'goals_scored_mean_upto_GW': nan,
#   'goals_scored_rolling_3GW': nan,
#   'goals_scored_rolling_5GW': nan,
#   'influence_mean_upto_GW': nan,
#   'influence_rolling_3GW': nan,
#   'influence_rolling_5GW': nan,
#   'red_cards_mean_upto_GW': nan,
#   'red_cards_rolling_3GW': nan,
#   'red_cards_rolling_5GW': nan,
#   'value_mean_upto_GW': nan,
#   'value_rolling_3GW': nan,
#   'value_rolling_5GW': nan,
#   'yellow_cards_mean_upto_GW': nan,
#   'yellow_cards_rolling_3GW': nan,
#   'yellow_cards_rolling_5GW': nan,
#   'new_player': 0,
#   'name:Aaron_Cresswell': 0,
#   'name:Aaron_Hickey': 0,
#   'name:Aaron_Ramsdale': 0,
#   'name:Aaron_Wan-Bissaka': 0,
#   'name:Abdoulaye_Doucouré': 0,
#   'name:Adam_Armstrong': 0,
#   'name:Adam_Forshaw': 0,
#   'name:Adam_Lallana': 0,
#   'name:Adam_Smith': 0,
#   'name:Adam_Webster': 0,
#   'name:Adama_Traoré_Diarra': 0,
#   'name:Adrián_San_Miguel_del_Castillo': 0,
#   'name:Ainsley_Maitland-Niles': 0,
#   'name:Albert_Sambi_Lokonga': 0,
#   'name:Alejandro_Garnacho': 0,
#   'name:Aleksandar_Mitrović': 0,
#   'name:Alex_Iwobi': 0,
#   'name:Alex_McCarthy': 0,
#   'name:Alex_Mighten': 0,
#   'name:Alex_Oxlade-Chamberlain': 0,
#   'name:Alex_Robertson': 0,
#   'name:Alex_Smithies': 0,
#   'name:Alex_Telles': 0,
#   'name:Alexander_Isak': 0,
#   'name:Alexandre_Moreno_Lopera': 0,
#   'name:Alexis_Mac_Allister': 0,
#   'name:Alfie_Devine': 0,
#   'name:Alfie_Gilchrist': 0,
#   'name:Alisson_Ramses_Becker': 0,
#   'name:Allan_Marques_Loureiro': 0,
#   'name:Allan_Saint-Maximin': 0,
#   'name:Alphonse_Areola': 0,
#   'name:Amad_Diallo': 0,
#   'name:Amadou_Onana': 0,
#   'name:Amario_Cozier-Duberry': 0,
#   'name:Andreas_Hoelgebaum_Pereira': 0,
#   'name:Andrew_Moran': 0,
#   'name:Andrew_Robertson': 0,
#   'name:Andrey_Nascimento_dos_Santos': 0,
#   'name:Andros_Townsend': 0,
#   'name:André_Ayew': 0,
#   'name:André_Tavares_Gomes': 0,
#   'name:Andy_Lonergan': 0,
#   'name:Angelo_Ogbonna': 0,
#   'name:Anthony_Elanga': 0,
#   'name:Anthony_Gordon': 0,
#   'name:Anthony_Knockaert': 0,
#   'name:Anthony_Martial': 0,
#   'name:Antoine_Semenyo': 0,
#   'name:Antonee_Robinson': 0,
#   'name:Antony_Matheus_dos_Santos': 0,
#   'name:Anwar_El_Ghazi': 0,
#   'name:Archie_Gray': 0,
#   'name:Armando_Broja': 0,
#   'name:Armel_Bella-Kotchap': 0,
#   'name:Armstrong_Oko-Flex': 0,
#   'name:Arnaut_Danjuma': 0,
#   'name:Arthur_Henrique_Ramos_de_Oliveira_Melo': 0,
#   'name:Arthur_Masuaku': 0,
#   'name:Ashley_Young': 0,
#   'name:Asmir_Begović': 0,
#   'name:Aymeric_Laporte': 0,
#   'name:Ayoze_Pérez': 0,
#   'name:Bashir_Humphreys': 0,
#   'name:Ben_Chilwell': 0,
#   'name:Ben_Davies': 0,
#   'name:Ben_Doak': 0,
#   'name:Ben_Godfrey': 0,
#   'name:Ben_Greenwood': 0,
#   'name:Ben_Johnson': 0,
#   'name:Ben_Knight': 0,
#   'name:Ben_Mee': 0,
#   'name:Ben_Pearson': 0,
#   'name:Benjamin_White': 0,
#   'name:Benoît_Badiashile': 0,
#   'name:Bernardo_Veiga_de_Carvalho_e_Silva': 0,
#   'name:Bernd_Leno': 0,
#   'name:Bertrand_Traoré': 0,
#   'name:Billy_Gilmour': 0,
#   'name:Bobby_Clark': 0,
#   'name:Bobby_De_Cordova-Reid': 0,
#   'name:Boubacar_Kamara': 0,
#   'name:Boubacar_Traoré': 0,
#   'name:Boubakary_Soumaré': 0,
#   'name:Braian_Ojeda_Rodríguez': 0,
#   'name:Brandon_Austin': 0,
#   'name:Brandon_Williams': 0,
#   'name:Brenden_Aaronson': 0,
#   'name:Brennan_Johnson': 0,
#   'name:Brice_Samba': 0,
#   'name:Bruno_Borges_Fernandes': 0,
#   'name:Bruno_Guimarães_Rodriguez_Moura': 0,
#   'name:Bryan_Gil_Salvatierra': 0,
#   'name:Bryan_Mbeumo': 0,
#   'name:Bukayo_Saka': 0,
#   'name:Callum_Hudson-Odoi': 0,
#   'name:Callum_Wilson': 0,
#   'name:Calum_Chambers': 0,
#   'name:Calvin_Ramsay': 0,
#   'name:Cameron_Archer': 0,
#   'name:Cameron_Peupion': 0,
#   'name:Cameron_Plain': 0,
#   'name:Caoimhin_Kelleher': 0,
#   'name:Carlos_Alcaraz': 0,
#   'name:Carlos_Henrique_Casimiro': 0,
#   'name:Carlos_Ribeiro_Dias': 0,
#   'name:Carlos_Vinícius_Alves_Morais': 0,
#   'name:Carney_Chukwuemeka': 0,
#   'name:Charlie_Goode': 0,
#   'name:Charlie_Robinson': 0,
#   'name:Che_Adams': 0,
#   'name:Cheick_Doucouré': 0,
#   'name:Cheikhou_Kouyaté': 0,
#   'name:Chem_Campbell': 0,
#   'name:Chris_Mepham': 0,
#   'name:Chris_Richards': 0,
#   'name:Chris_Wood': 0,
#   'name:Christian_Benteke': 0,
#   'name:Christian_Eriksen': 0,
#   'name:Christian_Nørgaard': 0,
#   'name:Christian_Pulisic': 0,
#   'name:Christian_Saydee': 0,
#   'name:Ciaran_Clark': 0,
#   'name:Claudio_Gomes': 0,
#   'name:Clément_Lenglet': 0,
#   'name:Cody_Drameh': 0,
#   'name:Cody_Gakpo': 0,
#   'name:Cole_Palmer': 0,
#   'name:Connor_Ronan': 0,
#   'name:Conor_Coady': 0,
#   'name:Conor_Coventry': 0,
#   'name:Conor_Gallagher': 0,
#   'name:Craig_Dawson': 0,
#   'name:Cristian_Romero': 0,
#   'name:Cristiano_Ronaldo_dos_Santos_Aveiro': 0,
#   'name:Crysencio_Summerville': 0,
#   'name:Curtis_Jones': 0,
#   'name:Cédric_Alves_Soares': 0,
#   'name:César_Azpilicueta': 0,
#   'name:Dale_Taylor': 0,
#   'name:Dan_Burn': 0,
#   'name:Dane_Scarlett': 0,
#   'name:Dango_Ouattara': 0,
#   'name:Daniel_Adu-Adjei': 0,
#   'name:Daniel_Amartey': 0,
#   'name:Daniel_Bentley': 0,
#   'name:Daniel_Castelo_Podence': 0,
#   'name:Daniel_Iversen': 0,
#   'name:Daniel_James': 0,
#   'name:Danilo_dos_Santos_de_Oliveira': 0,
#   'name:Danny_Ings': 0,
#   'name:Danny_Ward': 0,
#   'name:Danny_Welbeck': 0,
#   'name:Darko_Gyabi': 0,
#   'name:Darren_Randolph': 0,
#   'name:Darwin_Núñez_Ribeiro': 0,
#   'name:David_Brooks': 0,
#   'name:David_Datro_Fofana': 0,
#   'name:David_De_Gea_Quintana': 0,
#   'name:David_Ozoh': 0,
#   'name:David_Raya_Martin': 0,
#   'name:Davinson_Sánchez': 0,
#   'name:Dean_Henderson': 0,
#   'name:Declan_Rice': 0,
#   'name:Dejan_Kulusevski': 0,
#   'name:Dele_Alli': 0,
#   'name:Demarai_Gray': 0,
#   'name:Denis_Zakaria': 0,
#   'name:Deniz_Undav': 0,
#   'name:Dennis_Praet': 0,
#   'name:Dexter_Lembikisa': 0,
#   'name:Diego_Carlos_Santos_Silva': 0,
#   'name:Diego_Da_Silva_Costa': 0,
#   'name:Diego_Llorente': 0,
#   'name:Diogo_Dalot_Teixeira': 0,
#   'name:Diogo_Pinheiro_Monteiro': 0,
#   'name:Diogo_Teixeira_da_Silva': 0,
#   'name:Divin_Mubama': 0,
#   'name:Djed_Spence': 0,
#   'name:Dominic_Ballard': 0,
#   'name:Dominic_Calvert-Lewin': 0,
#   'name:Dominic_Sadi': 0,
#   'name:Dominic_Solanke': 0,
#   'name:Dominic_Thompson': 0,
#   'name:Donny_van_de_Beek': 0,
#   'name:Douglas_Luiz_Soares_de_Paulo': 0,
#   'name:Duje_Caleta-Car': 0,
#   'name:Dwight_Gayle': 0,
#   'name:Dwight_McNeil': 0,
#   'name:Eberechi_Eze': 0,
#   'name:Ed_Turns': 0,
#   'name:Eddie_Nketiah': 0,
#   'name:Ederson_Santana_de_Moraes': 0,
#   'name:Edouard_Mendy': 0,
#   'name:Eldin_Jakupovic': 0,
#   'name:Ellery_Balcombe': 0,
#   'name:Elliot_Anderson': 0,
#   'name:Ellis_Simms': 0,
#   'name:Emerson_Leite_de_Souza_Junior': 0,
#   'name:Emerson_Palmieri_dos_Santos': 0,
#   'name:Emil_Krafth': 0,
#   'name:Emile_Smith_Rowe': 0,
#   'name:Emiliano_Buendía_Stati': 0,
#   'name:Emiliano_Marcondes': 0,
#   'name:Emiliano_Martínez_Romero': 0,
#   'name:Emmanuel_Dennis': 0,
#   'name:Enock_Mwepu': 0,
#   'name:Enzo_Fernández': 0,
#   'name:Eric_Bailly': 0,
#   'name:Eric_Dier': 0,
#   'name:Erling_Haaland': 0,
#   'name:Ethan_Ampadu': 0,
#   'name:Ethan_Nwaneri': 0,
#   'name:Ethan_Pinnock': 0,
#   'name:Ethan_Wady': 0,
#   'name:Euan_Pollock': 0,
#   'name:Evan_Ferguson': 0,
#   'name:Ezri_Konsa_Ngoyo': 0,
#   'name:Fabian_Schär': 0,
#   'name:Fabio_Henrique_Tavares': 0,
#   'name:Fabio_Silva': 0,
#   'name:Facundo_Buonanotte': 0,
#   'name:Facundo_Pellistri_Rebollo': 0,
#   'name:Federico_Fernández': 0,
#   'name:Felipe_Augusto_de_Almeida_Monteiro': 0,
#   'name:Filip_Marschall': 0,
#   'name:Fin_Stevens': 0,
#   'name:Flynn_Downes': 0,
#   'name:Francisco_Jorge_Tomás_Oliveira': 0,
#   'name:Frank_Onyeka': 0,
#   'name:Fraser_Forster': 0,
#   'name:Frederico_Rodrigues_de_Paula_Santos': 0,
#   'name:Frédéric_Guilbert': 0,
#   'name:Fábio_Ferreira_Vieira': 0,
#   'name:Fábio_Freitas_Gouveia_Carvalho': 0,
#   'name:Gabriel_Fernando_de_Jesus': 0,
#   'name:Gabriel_Martinelli_Silva': 0,
#   'name:Gabriel_dos_Santos_Magalhães': 0,
#   'name:Garang_Kuol': 0,
#   'name:Gavin_Bazunu': 0,
#   'name:George_Abbott': 0,
#   'name:George_Shelvey': 0,
#   'name:George_Wickens': 0,
#   'name:Georginio_Rutter': 0,
#   'name:Gianluca_Scamacca': 0,
#   'name:Giulian_Biancone': 0,
#   'name:Gonçalo_Manuel_Ganchinho_Guedes': 0,
#   'name:Granit_Xhaka': 0,
#   'name:Gustavo_Henrique_Furtado_Scarpa': 0,
#   'name:Hakim_Ziyech': 0,
#   'name:Halil_Dervişoğlu': 0,
#   'name:Hamed_Traorè': 0,
#   'name:Hamza_Choudhury': 0,
#   'name:Harrison_Ashby': 0,
#   'name:Harrison_Reed': 0,
#   'name:Harry_Arter': 0,
#   'name:Harry_Kane': 0,
#   'name:Harry_Maguire': 0,
#   'name:Harry_Souttar': 0,
#   'name:Harry_Toffolo': 0,
#   'name:Harry_Wilson': 0,
#   'name:Harry_Winks': 0,
#   'name:Harvey_Barnes': 0,
#   'name:Harvey_Davies': 0,
#   'name:Harvey_Elliott': 0,
#   'name:Harvey_Griffiths': 0,
#   'name:Harvey_Vale': 0,
#   'name:Harvey_White': 0,
#   'name:Haydon_Roberts': 0,
#   'name:Hugo_Bueno_López': 0,
#   'name:Hugo_Lloris': 0,
#   'name:Hwang_Hee-chan': 0,
#   'name:Ibrahima_Diallo': 0,
#   'name:Ibrahima_Konaté': 0,
#   'name:Idrissa_Gueye': 0,
#   'name:Ilkay_Gündogan': 0,
#   'name:Illan_Meslier': 0,
#   'name:Illia_Zabarnyi': 0,
#   'name:Imari_Samuels': 0,
#   'name:Isaac_Price': 0,
#   'name:Ishé_Samuels-Smith': 0,
#   'name:Issa_Diop': 0,
#   'name:Ivan_Neves_Abreu_Cavaleiro': 0,
#   'name:Ivan_Perišić': 0,
#   'name:Ivan_Toney': 0,
#   'name:Jack_Butland': 0,
#   'name:Jack_Colback': 0,
#   'name:Jack_Grealish': 0,
#   'name:Jack_Harrison': 0,
#   'name:Jack_Hinshelwood': 0,
#   'name:Jack_Stacey': 0,
#   'name:Jack_Stephens': 0,
#   'name:Jack_Wells-Morrison': 0,
#   'name:Jackson_Smith': 0,
#   'name:Jacob_Murphy': 0,
#   'name:Jacob_Ramsey': 0,
#   'name:Jaden_Philogene-Bidace': 0,
#   'name:Jadon_Sancho': 0,
#   'name:Jaidon_Anthony': 0,
#   'name:Jairo_Riedewald': 0,
#   'name:Jakub_Kiwior': 0,
#   'name:Jakub_Moder': 0,
#   'name:Jamaal_Lascelles': 0,
#   'name:Jamal_Lewis': 0,
#   'name:Jamal_Lowe': 0,
#   'name:James_Bree': 0,
#   'name:James_Furlong': 0,
#   'name:James_Garner': 0,
#   'name:James_Hill': 0,
#   'name:James_Justin': 0,
#   'name:James_Maddison': 0,
#   'name:James_McArthur': 0,
#   'name:James_McAtee': 0,
#   'name:James_Milner': 0,
#   'name:James_Tarkowski': 0,
#   'name:James_Tomkins': 0,
#   'name:James_Ward-Prowse': 0,
#   'name:James_Wright': 0,
#   'name:Jamie_Shackleton': 0,
#   'name:Jamie_Vardy': 0,
#   'name:Jan_Bednarek': 0,
#   'name:Jan_Paul_van_Hecke': 0,
#   'name:Jannik_Vestergaard': 0,
#   'name:Japhet_Tanganga': 0,
#   'name:Jarrad_Branthwaite': 0,
#   'name:Jarrod_Bowen': 0,
#   'name:Jason_Steele': 0,
#   'name:Javier_Manquillo_Gaitán': 0,
#   'name:Jay_Stansfield': 0,
#   'name:Jean-Philippe_Gbamin': 0,
#   'name:Jean-Philippe_Mateta': 0,
#   'name:Jeff_Hendrick': 0,
#   'name:Jefferson_Lerma_Solís': 0,
#   'name:Jeffrey_Schlupp': 0,
#   'name:Jeremiah_Chilokoa-Mullen': 0,
#   'name:Jeremy_Sarmiento_Morante': 0,
#   'name:Jesse_Lingard': 0,
#   'name:Jesurun_Rak-Sakyi': 0,
#   'name:Jhon_Durán': 0,
#   'name:Jimmy_Morgan': 0,
#   'name:Joachim_Andersen': 0,
#   'name:Joe_Ayodele-Aribo': 0,
#   'name:Joe_Bryan': 0,
#   'name:Joe_Gelhardt': 0,
#   'name:Joe_Lolley': 0,
#   'name:Joe_Rodon': 0,
#   'name:Joe_Rothwell': 0,
#   'name:Joe_Willock': 0,
#   'name:Joe_Wormleighton': 0,
#   'name:Joe_Worrall': 0,
#   'name:Joel_Matip': 0,
#   'name:Joel_Robles': 0,
#   'name:Joel_Ward': 0,
#   'name:Joelinton_Cássio_Apolinário_de_Lira': 0,
#   'name:John-Kymani_Gordon': 0,
#   'name:John_McGinn': 0,
#   'name:John_Stones': 0,
#   'name:Jonathan_Castro_Otto': 0,
#   'name:Jonathan_Panzo': 0,
#   'name:Jonjo_Shelvey': 0,
#   'name:Jonny_Evans': 0,
#   'name:Jordan_Ayew': 0,
#   'name:Jordan_Henderson': 0,
#   'name:Jordan_Pickford': 0,
#   'name:Jordan_Smith': 0,
#   'name:Jordan_Zemura': 0,
#   'name:Jorge_Luiz_Frello_Filho': 0,
#   'name:Joseph_Anang': 0,
#   'name:Joseph_Gomez': 0,
#   'name:Joseph_Hodge': 0,
#   'name:Joseph_Whitworth': 0,
#   'name:Josh_Dasilva': 0,
#   'name:Josh_Onomah': 0,
#   'name:Josh_Wilson-Esbrand': 0,
#   'name:José_Malheiro_de_Sá': 0,
#   'name:João_Cancelo': 0,
#   'name:João_Filipe_Iria_Santos_Moutinho': 0,
#   'name:João_Félix_Sequeira': 0,
#   'name:João_Palhinha_Gonçalves': 0,
#   'name:João_Victor_Gomes_da_Silva': 0,
#   'name:Joël_Veltman': 0,
#   'name:Juan_Larios_López': 0,
#   'name:Julio_Enciso': 0,
#   'name:Julián_Álvarez': 0,
#   'name:Junior_Firpo_Adames': 0,
#   'name:Junior_Stanislas': 0,
#   'name:Kacper_Kozłowski': 0,
#   'name:Kadan_Young': 0,
#   'name:Kaden_Rodney': 0,
#   'name:Kaelan_Casey': 0,
#   'name:Kai_Havertz': 0,
#   'name:Kaine_Kesler_Hayden': 0,
#   'name:Kalidou_Koulibaly': 0,
#   'name:Kalvin_Phillips': 0,
#   'name:Kamaldeen_Sulemana': 0,
#   'name:Kamari_Doyle': 0,
#   'name:Kaoru_Mitoma': 0,
#   'name:Karl_Darlow': 0,
#   'name:Karl_Hein': 0,
#   'name:Kasey_McAteer': 0,
#   'name:Kasper_Schmeichel': 0,
#   'name:Keane_Lewis-Potter': 0,
#   'name:Keinan_Davis': 0,
#   'name:Kelechi_Iheanacho': 0,
#   'name:Kenny_Tete': 0,
#   'name:Kepa_Arrizabalaga': 0,
#   'name:Kevin_De_Bruyne': 0,
#   'name:Kevin_Mbabu': 0,
#   'name:Kevin_Schade': 0,
#   'name:Keylor_Navas': 0,
#   'name:Kieffer_Moore': 0,
#   'name:Kieran_Tierney': 0,
#   'name:Kieran_Trippier': 0,
#   'name:Kiernan_Dewsbury-Hall': 0,
#   'name:Killian_Phillips': 0,
#   'name:Kjell_Scherpen': 0,
#   'name:Kobbie_Mainoo': 0,
#   'name:Kofi_Balmer': 0,
#   'name:Konstantinos_Tsimikas': 0,
#   'name:Kortney_Hause': 0,
#   'name:Kristian_Sekularac': 0,
#   'name:Kristoffer_Ajer': 0,
#   'name:Kristoffer_Klaesson': 0,
#   'name:Krisztián_Hegyi': 0,
#   'name:Kurt_Zouma': 0,
#   'name:Kyle_John': 0,
#   'name:Kyle_Walker': 0,
#   'name:Kyle_Walker-Peters': 0,
#   'name:Lamare_Bogarde': 0,
#   'name:Layvin_Kurzawa': 0,
#   'name:Leander_Dendoncker': 0,
#   'name:Leandro_Trossard': 0,
#   'name:Leo_Fuhr_Hjelde': 0,
#   'name:Leon_Bailey': 0,
#   'name:Levi_Colwill': 0,
#   'name:Lewis_Bate': 0,
#   'name:Lewis_Brunt': 0,
#   'name:Lewis_Cook': 0,
#   'name:Lewis_Dunk': 0,
#   'name:Lewis_Hall': 0,
#   'name:Lewis_Miley': 0,
#   "name:Lewis_O'Brien": 0,
#   'name:Lewis_Payne': 0,
#   'name:Lewis_Warrington': 0,
#   'name:Liam_Cooper': 0,
#   'name:Liam_Delap': 0,
#   'name:Lino_Sousa': 0,
#   'name:Lisandro_Martínez': 0,
#   'name:Lloyd_Kelly': 0,
#   'name:Loris_Karius': 0,
#   'name:Loïc_Badé': 0,
#   'name:Loïc_Mbe_Soh': 0,
#   'name:Lucas_Digne': 0,
#   'name:Lucas_Rodrigues_Moura_da_Silva': 0,
#   'name:Lucas_Tolentino_Coelho_de_Lima': 0,
#   'name:Lucas_Torreira_di_Pascua': 0,
#   'name:Ludwig_Augustinsson': 0,
#   'name:Luis_Díaz': 0,
#   'name:Luis_Sinisterra_Lucumí': 0,
#   'name:Luka_Milivojevic': 0,
#   'name:Lukasz_Fabianski': 0,
#   'name:Luke_Ayling': 0,
#   'name:Luke_Chambers': 0,
#   'name:Luke_Cundle': 0,
#   'name:Luke_Harris': 0,
#   'name:Luke_Mbete-Tabu': 0,
#   'name:Luke_Plange': 0,
#   'name:Luke_Shaw': 0,
#   'name:Luke_Thomas': 0,
#   'name:Lyanco_Silveira_Neves_Vojnovic': 0,
#   'name:Lyle_Taylor': 0,
#   'name:Mads_Bech_Sørensen': 0,
#   'name:Mads_Bidstrup': 0,
#   'name:Mads_Roerslev_Rasmussen': 0,
#   'name:Malang_Sarr': 0,
#   'name:Malcolm_Ebiowei': 0,
#   'name:Manor_Solomon': 0,
#   'name:Manuel_Akanji': 0,
#   'name:Manuel_Lanzini': 0,
#   'name:Marc_Albrighton': 0,
#   'name:Marc_Cucurella_Saseta': 0,
#   'name:Marc_Guéhi': 0,
#   'name:Marc_Jurado_Gomez': 0,
#   'name:Marc_Roca_Junqué': 0,
#   'name:Marcel_Sabitzer': 0,
#   'name:Marcos_Alonso': 0,
#   'name:Marcos_Senesi': 0,
#   'name:Marcus_Bettinelli': 0,
#   'name:Marcus_Forss': 0,
#   'name:Marcus_Oliveira_Alencar': 0,
#   'name:Marcus_Rashford': 0,
#   'name:Marcus_Tavernier': 0,
#   'name:Marek_Rodák': 0,
#   'name:Mario_Lemina': 0,
#   'name:Mark_Gillespie': 0,
#   'name:Mark_Travers': 0,
#   'name:Martial_Godo': 0,
#   'name:Martin_Dubravka': 0,
#   'name:Martin_Ødegaard': 0,
#   'name:Marvelous_Nakamba': 0,
#   'name:Mason_Holgate': 0,
#   'name:Mason_Mount': 0,
#   'name:Matej_Kovár': 0,
#   'name:Mateo_Joseph_Fernández': 0,
#   'name:Mateo_Kovacic': 0,
#   'name:Mateus_Cardoso_Lemos_Martins': 0,
#   'name:Mateusz_Klich': 0,
#   'name:Mateusz_Lis': 0,
#   'name:Matheus_Luiz_Nunes': 0,
#   'name:Matheus_Santos_Carneiro_Da_Cunha': 0,
#   'name:Mathias_Jensen': 0,
#   'name:Mathias_Jorgensen': 0,
#   'name:Matija_Šarkić': 0,
#   'name:Matt_Clarke': 0,
#   'name:Matt_Doherty': 0,
#   'name:Matt_Ritchie': 0,
#   'name:Matt_Targett': 0,
#   'name:Matt_Turner': 0,
#   'name:Matthew_Cox': 0,
#   'name:Matthew_Craig': 0,
#   'name:Matthew_Dibley-Dias': 0,
#   'name:Matthew_Smith': 0,
#   'name:Matty_Cash': 0,
#   'name:Matías_Viña': 0,
#   'name:Mauro_Bandeira': 0,
#   'name:Max_Kilman': 0,
#   'name:Max_Kinsey-Wellings': 0,
#   'name:Maximilian_Wöber': 0,
#   'name:Maxwel_Cornet': 0,
#   'name:Michael_Dacosta_Gonzalez': 0,
#   'name:Michael_Keane': 0,
#   'name:Michael_Olakigbe': 0,
#   'name:Michael_Olise': 0,
#   'name:Michail_Antonio': 0,
#   'name:Miguel_Almirón_Rejala': 0,
#   'name:Mikkel_Damsgaard': 0,
#   'name:Mislav_Orsic': 0,
#   'name:Mohamed_Dräger': 0,
#   'name:Mohamed_Elneny': 0,
#   'name:Mohamed_Elyounoussi': 0,
#   'name:Mohamed_Salah': 0,
#   'name:Mohammed_Salisu': 0,
#   'name:Moisés_Caicedo_Corozo': 0,
#   'name:Morgan_Gibbs-White': 0,
#   'name:Morgan_Sanson': 0,
#   'name:Moussa_Djenepo': 0,
#   'name:Moussa_Niakhaté': 0,
#   'name:Mykhailo_Mudryk': 0,
#   'name:Máximo_Perrone': 0,
#   "name:N'Golo_Kanté": 0,
#   'name:Naby_Keita': 0,
#   'name:Nampalys_Mendy': 0,
#   'name:Naouirou_Ahamada': 0,
#   'name:Nathan_Aké': 0,
#   'name:Nathan_Bishop': 0,
#   'name:Nathan_Butler-Oyedeji': 0,
#   'name:Nathan_Collins': 0,
#   'name:Nathan_Ferguson': 0,
#   'name:Nathan_Fraser': 0,
#   'name:Nathan_Patterson': 0,
#   'name:Nathan_Redmond': 1,
#   'name:Nathan_Tella': 0,
#   'name:Nathaniel_Chalobah': 0,
#   'name:Nathaniel_Clyne': 0,
#   'name:Nathaniel_Phillips': 0,
#   'name:Nayef_Aguerd': 0,
#   'name:Neal_Maupay': 0,
#   'name:Neco_Williams': 0,
#   'name:Neeskens_Kebano': 0,
#   'name:Nick_Pope': 0,
#   "name:Nico_O'Reilly": 0,
#   'name:Nicolas_Pépé': 0,
#   'name:Niels_Nkounkou': 0,
#   'name:Nikola_Vlasic': 0,
#   'name:Noni_Madueke': 0,
#   'name:Norberto_Murara_Neto': 0,
#   'name:Nuno_Varela_Tavares': 0,
#   'name:Nélson_Cabral_Semedo': 0,
#   'name:Odeluga_Offiah': 0,
#   'name:Odsonne_Edouard': 0,
#   'name:Oleksandr_Zinchenko': 0,
#   'name:Oliver_Hammond': 0,
#   'name:Oliver_Skipp': 0,
#   'name:Oliwier_Zych': 0,
#   'name:Ollie_Watkins': 0,
#   'name:Omar_Richards': 0,
#   'name:Omari_Hutchinson': 0,
#   'name:Orel_Mangala': 0,
#   'name:Oriol_Romeu_Vidal': 0,
#   'name:Owen_Bevan': 0,
#   'name:Owen_Goodman': 0,
#   'name:Pablo_Fornals_Malla': 0,
#   'name:Pablo_Marí_Villar': 0,
#   'name:Pablo_Sarabia': 0,
#   'name:Pape_Matar_Sarr': 0,
#   'name:Pascal_Groß': 0,
#   'name:Pascal_Struijk': 0,
#   'name:Patrick_Bamford': 0,
#   'name:Patson_Daka': 0,
#   'name:Paul_Dummett': 0,
#   'name:Paul_Onuachu': 0,
#   'name:Paulo_Gazzaniga_Farias': 0,
#   'name:Pedro_Lomba_Neto': 0,
#   'name:Pedro_Porro': 0,
#   'name:Pervis_Estupiñán': 0,
#   'name:Phil_Foden': 0,
#   'name:Phil_Jones': 0,
#   'name:Philip_Billing': 0,
#   'name:Philippe_Coutinho_Correia': 0,
#   'name:Pierre-Emerick_Aubameyang': 0,
#   'name:Pierre-Emile_Højbjerg': 0,
#   'name:Pontus_Jansson': 0,
#   'name:Raheem_Sterling': 0,
#   'name:Raphael_Dias_Belloli': 0,
#   'name:Raphaël_Varane': 0,
#   'name:Rasmus_Kristensen': 0,
#   'name:Rayan_Aït-Nouri': 0,
#   'name:Raúl_Jiménez': 0,
#   'name:Reece_James': 0,
#   'name:Reece_Welch': 0,
#   'name:Reiss_Nelson': 0,
#   'name:Remi_Matthews': 0,
#   'name:Remo_Freuler': 0,
#   'name:Renan_Augusto_Lodi_dos_Santos': 0,
#   'name:Reuell_Walters': 0,
#   'name:Rhys_Bennett': 0,
#   'name:Rhys_Williams': 0,
#   'name:Ricardo_Barbosa_Pereira': 0,
#   'name:Richarlison_de_Andrade': 0,
#   'name:Richie_Laryea': 0,
#   'name:Rico_Henry': 0,
#   'name:Rico_Lewis': 0,
#   'name:Riyad_Mahrez': 0,
#   'name:Rob_Holding': 0,
#   'name:Robert_Kenedy_Nunes_do_Nascimento': 0,
#   'name:Robert_Sánchez': 0,
#   'name:Roberto_Firmino': 0,
#   'name:Robin_Koch': 0,
#   'name:Robin_Olsen': 0,
#   'name:Rodrigo_Bentancur': 0,
#   'name:Rodrigo_Hernandez': 0,
#   'name:Rodrigo_Moreno': 0,
#   'name:Rodrigo_Muniz_Carvalho': 0,
#   'name:Romain_Perraud': 0,
#   'name:Romaine_Mundle': 0,
#   'name:Roméo_Lavia': 0,
#   'name:Ross_Barkley': 0,
#   'name:Ruben_Loftus-Cheek': 0,
#   'name:Ryan_Bertrand': 0,
#   'name:Ryan_Christie': 0,
#   'name:Ryan_Finnigan': 0,
#   'name:Ryan_Fraser': 0,
#   'name:Ryan_Fredericks': 0,
#   'name:Ryan_Sessegnon': 0,
#   'name:Ryan_Trevitt': 0,
#   'name:Ryan_Yates': 0,
#   'name:Rúben_Gato_Alves_Dias': 0,
#   'name:Rúben_Nascimento_Vinagre': 0,
#   'name:Rúben_da_Silva_Neves': 0,
#   'name:Salomón_Rondón': 0,
#   'name:Sam_Greenwood': 0,
#   'name:Sam_Johnstone': 0,
#   'name:Sam_Surridge': 0,
#   'name:Saman_Ghoddos': 0,
#   'name:Sammy_Braybrooke': 0,
#   'name:Samuel_Amo-Ameyaw': 0,
#   'name:Samuel_Edozie': 0,
#   'name:Sasa_Kalajdzic': 0,
#   'name:Sasa_Lukic': 0,
#   'name:Saïd_Benrahma': 0,
#   'name:Scott_Carson': 0,
#   'name:Scott_McKenna': 0,
#   'name:Scott_McTominay': 0,
#   'name:Seamus_Coleman': 0,
#   'name:Sean_Longstaff': 0,
#   'name:Sean_McAllister': 0,
#   'name:Sebastian_Revan': 0,
#   'name:Sepp_van_den_Berg': 0,
#   'name:Serge_Aurier': 0,
#   'name:Sergi_Canós_Tenés': 0,
#   'name:Sergio_Gómez': 0,
#   'name:Sergio_Reguilón': 0,
#   'name:Shandon_Baptiste': 0,
#   'name:Shane_Duffy': 0,
#   'name:Shea_Charles': 0,
#   'name:Shola_Shoretire': 0,
#   'name:Sil_Swinkels': 0,
#   'name:Siriki_Dembélé': 0,
#   'name:Solly_March': 0,
#   'name:Son_Heung-min': 0,
#   'name:Sonny_Perkins': 0,
#   'name:Stanley_Mills': 0,
#   'name:Stefan_Bajcetic': 0,
#   'name:Stefan_Ortega_Moreno': 0,
#   'name:Stefan_Parkes': 0,
#   'name:Steve_Cook': 0,
#   'name:Steven_Alzate': 0,
#   'name:Steven_Bergwijn': 0,
#   'name:Stuart_Armstrong': 0,
#   'name:Stuart_Dallas': 0,
#   'name:Sven_Botman': 0,
#   'name:Sékou_Mara': 0,
#   'name:Taiwo_Awoniyi': 0,
#   'name:Takehiro_Tomiyasu': 0,
#   'name:Tariq_Lamptey': 0,
#   'name:Taylor_Richards': 0,
#   'name:Tayo_Adaramola': 0,
#   'name:Terence_Kongolo': 0,
#   'name:Terry_Ablade': 0,
#   'name:Theo_Walcott': 0,
#   'name:Thiago_Alcántara_do_Nascimento': 0,
#   'name:Thiago_Emiliano_da_Silva': 0,
#   'name:Thilo_Kehrer': 0,
#   'name:Thomas_Cannon': 0,
#   'name:Thomas_Partey': 0,
#   'name:Thomas_Strakosha': 0,
#   'name:Tim_Iroegbunam': 0,
#   'name:Tim_Ream': 0,
#   'name:Timo_Werner': 0,
#   'name:Timothy_Castagne': 0,
#   'name:Tino_Livramento': 0,
#   'name:Tom_Cairney': 0,
#   'name:Tom_Davies': 0,
#   'name:Tom_Heaton': 0,
#   'name:Tom_McGill': 0,
#   'name:Tomas_Soucek': 0,
#   "name:Tommi_O'Reilly": 0,
#   'name:Tosin_Adarabioyo': 0,
#   'name:Toti_António_Gomes': 0,
#   'name:Travis_Patterson': 0,
#   'name:Trent_Alexander-Arnold': 0,
#   'name:Trevoh_Chalobah': 0,
#   'name:Tristan_Crama': 0,
#   'name:Troy_Parrott': 0,
#   'name:Tyler_Adams': 0,
#   'name:Tyler_Roberts': 0,
#   'name:Tyrell_Malacia': 0,
#   'name:Tyrese_Francois': 0,
#   'name:Tyrick_Mitchell': 0,
#   'name:Tyrone_Mings': 0,
#   'name:Vicente_Guaita': 0,
#   'name:Victor_Kristiansen': 0,
#   'name:Victor_Lindelöf': 0,
#   'name:Viljami_Sinisalo': 0,
#   'name:Virgil_van_Dijk': 0,
#   'name:Vitalii_Mykolenko': 0,
#   'name:Vitaly_Janelt': 0,
#   'name:Vladimir_Coufal': 0,
#   'name:Wanya_Marçal-Madivadua': 0,
#   'name:Wayne_Hennessey': 0,
#   'name:Wesley_Fofana': 0,
#   'name:Weston_McKennie': 0,
#   'name:Wilfred_Ndidi': 0,
#   'name:Wilfried_Gnonto': 0,
#   'name:Wilfried_Zaha': 0,
#   'name:Will_Dennis': 0,
#   'name:Will_Hughes': 0,
#   'name:Will_Smallbone': 0,
#   'name:William_Saliba': 0,
#   'name:Willian_Borges_da_Silva': 0,
#   'name:Willy_Boly': 0,
#   'name:Willy_Caballero': 0,
#   'name:Wout_Faes': 0,
#   'name:Wout_Weghorst': 0,
#   'name:Xande_Nascimento_da_Costa_Silva': 0,
#   'name:Yago_de_Santiago_Alonso': 0,
#   'name:Yan_Valery': 0,
#   'name:Yasin_Ayari': 0,
#   'name:Yegor_Yarmolyuk': 0,
#   'name:Yerry_Mina': 0,
#   'name:Yerson_Mosquera_Valdelamar': 0,
#   'name:Yoane_Wissa': 0,
#   'name:Youri_Tielemans': 0,
#   'name:Yves_Bissouma': 0,
#   'name:Zack_Steffen': 0,
#   'name:Zidane_Iqbal': 0,
#   'name:Çaglar_Söyüncü': 0,
#   'position:DEF': 0,
#   'position:FWD': 0,
#   'position:GK': 0,
#   'position:MID': 1,
#   'team:Arsenal': 0,
#   'team:Aston Villa': 0,
#   'team:Bournemouth': 0,
#   'team:Brentford': 0,
#   'team:Brighton': 0,
#   'team:Chelsea': 0,
#   'team:Crystal Palace': 0,
#   'team:Everton': 0,
#   'team:Fulham': 0,
#   'team:Leeds': 0,
#   'team:Leicester': 0,
#   'team:Liverpool': 0,
#   'team:Man City': 0,
#   'team:Man Utd': 0,
#   'team:Newcastle': 0,
#   "team:Nott'm Forest": 0,
#   'team:Southampton': 1,
#   'team:Spurs': 0,
#   'team:West Ham': 0,
#   'team:Wolves': 0,
#   'GW:0': 1,
#   'GW:1': 0,
#   'GW:2': 0,
#   'GW:3': 0,
#   'GW:4': 0,
#   'GW:5': 0,
#   'GW:6': 0,
#   'GW:7': 0,
#   'GW:8': 0,
#   'GW:9': 0,
#   'GW:10': 0,
#   'GW:11': 0,
#   'GW:12': 0,
#   'GW:13': 0,
#   'GW:14': 0,
#   'GW:15': 0,
#   'GW:16': 0,
#   'GW:17': 0,
#   'GW:18': 0,
#   'GW:19': 0,
#   'GW:20': 0,
#   'GW:21': 0,
#   'GW:22': 0,
#   'GW:23': 0,
#   'GW:24': 0,
#   'GW:25': 0,
#   'GW:26': 0,
#   'GW:27': 0,
#   'GW:28': 0,
#   'GW:29': 0,
#   'GW:30': 0,
#   'GW:31': 0,
#   'GW:32': 0,
#   'GW:33': 0,
#   'GW:34': 0,
#   'GW:35': 0,
#   'GW:36': 0,
#   'GW:37': 0,
#   'GW:38': 0}]

# %%
##################################################################################################
## -- create Player and Team class Definitions
##################################################################################################

# Player
class Player:
    def __init__(self, **kwargs):
        self.points = 0
        for key, value in kwargs.items():
            setattr(self, key, value)

# Create list of Player Objects
all_available_players = []

for player in player_dict:
    player_to_add = Player(**player_dict[player][0])
    all_available_players.append(player_to_add)
            
# Team
class Team:
    def __init__(self):
        self.original_budget = 100_000_000
        self.dynamic_budget = self.original_budget # Budget that gets updated each game week as players value changes
        self.players = []
        self.team_points = 0
        self.MAX_POSITIONS = {'GK': 1,'DEF': 4,'MID': 4,'FWD': 2}

    def add_player(self, player):
        if player.value <= self.dynamic_budget:
            self.players.append(player)
            self.dynamic_budget -= player.value

    def remove_player(self, player):
        self.players.remove(player)
        self.dynamic_budget += player.value

    def update_team_points(self):
        self.team_points += sum(player.gw_points for player in self.players)

    def can_player_be_added_based_on_position(self, player):
        # Check the number of players of this position in the current team and compare with maximum allowed
        players_of_same_position = [p for p in self.players if p.position == player.position]
        return len(players_of_same_position) < self.MAX_POSITIONS[player.position]

# %%
x =1
x
# Out:
# 1

# %%
# Assuming you have an existing Player object
existing_player = all_available_players[0]  # Replace with the actual index of your player

# List all attributes
for attribute in dir(existing_player):
    if not attribute.startswith("__"):  # Exclude built-in attributes
        print(f"{attribute}: {getattr(existing_player, attribute)}")
# Out:
# 0    0
# Name: GW, dtype: int64
# 0    1
# Name: GW:0, dtype: int32
# 0    0
# Name: GW:1, dtype: int32
# 0    0
# Name: GW:10, dtype: int32
# 0    0
# Name: GW:11, dtype: int32
# 0    0
# Name: GW:12, dtype: int32
# 0    0
# Name: GW:13, dtype: int32
# 0    0
# Name: GW:14, dtype: int32
# 0    0
# Name: GW:15, dtype: int32
# 0    0
# Name: GW:16, dtype: int32
# 0    0
# Name: GW:17, dtype: int32
# 0    0
# Name: GW:18, dtype: int32
# 0    0
# Name: GW:19, dtype: int32
# 0    0
# Name: GW:2, dtype: int32
# 0    0
# Name: GW:20, dtype: int32
# 0    0
# Name: GW:21, dtype: int32
# 0    0
# Name: GW:22, dtype: int32
# 0    0
# Name: GW:23, dtype: int32
# 0    0
# Name: GW:24, dtype: int32
# 0    0
# Name: GW:25, dtype: int32
# 0    0
# Name: GW:26, dtype: int32
# 0    0
# Name: GW:27, dtype: int32
# 0    0
# Name: GW:28, dtype: int32
# 0    0
# Name: GW:29, dtype: int32
# 0    0
# Name: GW:3, dtype: int32
# 0    0
# Name: GW:30, dtype: int32
# 0    0
# Name: GW:31, dtype: int32
# 0    0
# Name: GW:32, dtype: int32
# 0    0
# Name: GW:33, dtype: int32
# 0    0
# Name: GW:34, dtype: int32
# 0    0
# Name: GW:35, dtype: int32
# 0    0
# Name: GW:36, dtype: int32
# 0    0
# Name: GW:37, dtype: int32
# 0    0
# Name: GW:38, dtype: int32
# 0    0
# Name: GW:4, dtype: int32
# 0    0
# Name: GW:5, dtype: int32
# 0    0
# Name: GW:6, dtype: int32
# 0    0
# Name: GW:7, dtype: int32
# 0    0
# Name: GW:8, dtype: int32
# 0    0
# Name: GW:9, dtype: int32
# 0   NaN
# Name: assists, dtype: float64
# 0   NaN
# Name: assists_mean_upto_GW, dtype: float64
# 0   NaN
# Name: assists_rolling_3GW, dtype: float64
# 0   NaN
# Name: assists_rolling_5GW, dtype: float64
# 0   NaN
# Name: clean_sheets, dtype: float64
# 0   NaN
# Name: clean_sheets_mean_upto_GW, dtype: float64
# 0   NaN
# Name: clean_sheets_rolling_3GW, dtype: float64
# 0   NaN
# Name: clean_sheets_rolling_5GW, dtype: float64
# 0   NaN
# Name: creativity, dtype: float64
# 0   NaN
# Name: creativity_mean_upto_GW, dtype: float64
# 0   NaN
# Name: creativity_rolling_3GW, dtype: float64
# 0   NaN
# Name: creativity_rolling_5GW, dtype: float64
# 0   NaN
# Name: fixture, dtype: float64
# 0   NaN
# Name: goals_conceded, dtype: float64
# 0   NaN
# Name: goals_conceded_mean_upto_GW, dtype: float64
# 0   NaN
# Name: goals_conceded_rolling_3GW, dtype: float64
# 0   NaN
# Name: goals_conceded_rolling_5GW, dtype: float64
# 0   NaN
# Name: goals_scored, dtype: float64
# 0   NaN
# Name: goals_scored_mean_upto_GW, dtype: float64
# 0   NaN
# Name: goals_scored_rolling_3GW, dtype: float64
# 0   NaN
# Name: goals_scored_rolling_5GW, dtype: float64
# 0   NaN
# Name: influence, dtype: float64
# 0   NaN
# Name: influence_mean_upto_GW, dtype: float64
# 0   NaN
# Name: influence_rolling_3GW, dtype: float64
# 0   NaN
# Name: influence_rolling_5GW, dtype: float64
# 0   NaT
# Name: kickoff_time, dtype: datetime64[ns]
# 0    55.0
# Name: last_season_value_max, dtype: float64
# 0    53.158
# Name: last_season_value_mean, dtype: float64
# 0    53.0
# Name: last_season_value_min, dtype: float64
# 0    Nathan_Redmond
# Name: name, dtype: object
# 0    0
# Name: name:Aaron_Cresswell, dtype: int32
# 0    0
# Name: name:Aaron_Hickey, dtype: int32
# 0    0
# Name: name:Aaron_Ramsdale, dtype: int32
# 0    0
# Name: name:Aaron_Wan-Bissaka, dtype: int32
# 0    0
# Name: name:Abdoulaye_Doucouré, dtype: int32
# 0    0
# Name: name:Adam_Armstrong, dtype: int32
# 0    0
# Name: name:Adam_Forshaw, dtype: int32
# 0    0
# Name: name:Adam_Lallana, dtype: int32
# 0    0
# Name: name:Adam_Smith, dtype: int32
# 0    0
# Name: name:Adam_Webster, dtype: int32
# 0    0
# Name: name:Adama_Traoré_Diarra, dtype: int32
# 0    0
# Name: name:Adrián_San_Miguel_del_Castillo, dtype: int32
# 0    0
# Name: name:Ainsley_Maitland-Niles, dtype: int32
# 0    0
# Name: name:Albert_Sambi_Lokonga, dtype: int32
# 0    0
# Name: name:Alejandro_Garnacho, dtype: int32
# 0    0
# Name: name:Aleksandar_Mitrović, dtype: int32
# 0    0
# Name: name:Alex_Iwobi, dtype: int32
# 0    0
# Name: name:Alex_McCarthy, dtype: int32
# 0    0
# Name: name:Alex_Mighten, dtype: int32
# 0    0
# Name: name:Alex_Oxlade-Chamberlain, dtype: int32
# 0    0
# Name: name:Alex_Robertson, dtype: int32
# 0    0
# Name: name:Alex_Smithies, dtype: int32
# 0    0
# Name: name:Alex_Telles, dtype: int32
# 0    0
# Name: name:Alexander_Isak, dtype: int32
# 0    0
# Name: name:Alexandre_Moreno_Lopera, dtype: int32
# 0    0
# Name: name:Alexis_Mac_Allister, dtype: int32
# 0    0
# Name: name:Alfie_Devine, dtype: int32
# 0    0
# Name: name:Alfie_Gilchrist, dtype: int32
# 0    0
# Name: name:Alisson_Ramses_Becker, dtype: int32
# 0    0
# Name: name:Allan_Marques_Loureiro, dtype: int32
# 0    0
# Name: name:Allan_Saint-Maximin, dtype: int32
# 0    0
# Name: name:Alphonse_Areola, dtype: int32
# 0    0
# Name: name:Amad_Diallo, dtype: int32
# 0    0
# Name: name:Amadou_Onana, dtype: int32
# 0    0
# Name: name:Amario_Cozier-Duberry, dtype: int32
# 0    0
# Name: name:Andreas_Hoelgebaum_Pereira, dtype: int32
# 0    0
# Name: name:Andrew_Moran, dtype: int32
# 0    0
# Name: name:Andrew_Robertson, dtype: int32
# 0    0
# Name: name:Andrey_Nascimento_dos_Santos, dtype: int32
# 0    0
# Name: name:Andros_Townsend, dtype: int32
# 0    0
# Name: name:André_Ayew, dtype: int32
# 0    0
# Name: name:André_Tavares_Gomes, dtype: int32
# 0    0
# Name: name:Andy_Lonergan, dtype: int32
# 0    0
# Name: name:Angelo_Ogbonna, dtype: int32
# 0    0
# Name: name:Anthony_Elanga, dtype: int32
# 0    0
# Name: name:Anthony_Gordon, dtype: int32
# 0    0
# Name: name:Anthony_Knockaert, dtype: int32
# 0    0
# Name: name:Anthony_Martial, dtype: int32
# 0    0
# Name: name:Antoine_Semenyo, dtype: int32
# 0    0
# Name: name:Antonee_Robinson, dtype: int32
# 0    0
# Name: name:Antony_Matheus_dos_Santos, dtype: int32
# 0    0
# Name: name:Anwar_El_Ghazi, dtype: int32
# 0    0
# Name: name:Archie_Gray, dtype: int32
# 0    0
# Name: name:Armando_Broja, dtype: int32
# 0    0
# Name: name:Armel_Bella-Kotchap, dtype: int32
# 0    0
# Name: name:Armstrong_Oko-Flex, dtype: int32
# 0    0
# Name: name:Arnaut_Danjuma, dtype: int32
# 0    0
# Name: name:Arthur_Henrique_Ramos_de_Oliveira_Melo, dtype: int32
# 0    0
# Name: name:Arthur_Masuaku, dtype: int32
# 0    0
# Name: name:Ashley_Young, dtype: int32
# 0    0
# Name: name:Asmir_Begović, dtype: int32
# 0    0
# Name: name:Aymeric_Laporte, dtype: int32
# 0    0
# Name: name:Ayoze_Pérez, dtype: int32
# 0    0
# Name: name:Bashir_Humphreys, dtype: int32
# 0    0
# Name: name:Ben_Chilwell, dtype: int32
# 0    0
# Name: name:Ben_Davies, dtype: int32
# 0    0
# Name: name:Ben_Doak, dtype: int32
# 0    0
# Name: name:Ben_Godfrey, dtype: int32
# 0    0
# Name: name:Ben_Greenwood, dtype: int32
# 0    0
# Name: name:Ben_Johnson, dtype: int32
# 0    0
# Name: name:Ben_Knight, dtype: int32
# 0    0
# Name: name:Ben_Mee, dtype: int32
# 0    0
# Name: name:Ben_Pearson, dtype: int32
# 0    0
# Name: name:Benjamin_White, dtype: int32
# 0    0
# Name: name:Benoît_Badiashile, dtype: int32
# 0    0
# Name: name:Bernardo_Veiga_de_Carvalho_e_Silva, dtype: int32
# 0    0
# Name: name:Bernd_Leno, dtype: int32
# 0    0
# Name: name:Bertrand_Traoré, dtype: int32
# 0    0
# Name: name:Billy_Gilmour, dtype: int32
# 0    0
# Name: name:Bobby_Clark, dtype: int32
# 0    0
# Name: name:Bobby_De_Cordova-Reid, dtype: int32
# 0    0
# Name: name:Boubacar_Kamara, dtype: int32
# 0    0
# Name: name:Boubacar_Traoré, dtype: int32
# 0    0
# Name: name:Boubakary_Soumaré, dtype: int32
# 0    0
# Name: name:Braian_Ojeda_Rodríguez, dtype: int32
# 0    0
# Name: name:Brandon_Austin, dtype: int32
# 0    0
# Name: name:Brandon_Williams, dtype: int32
# 0    0
# Name: name:Brenden_Aaronson, dtype: int32
# 0    0
# Name: name:Brennan_Johnson, dtype: int32
# 0    0
# Name: name:Brice_Samba, dtype: int32
# 0    0
# Name: name:Bruno_Borges_Fernandes, dtype: int32
# 0    0
# Name: name:Bruno_Guimarães_Rodriguez_Moura, dtype: int32
# 0    0
# Name: name:Bryan_Gil_Salvatierra, dtype: int32
# 0    0
# Name: name:Bryan_Mbeumo, dtype: int32
# 0    0
# Name: name:Bukayo_Saka, dtype: int32
# 0    0
# Name: name:Callum_Hudson-Odoi, dtype: int32
# 0    0
# Name: name:Callum_Wilson, dtype: int32
# 0    0
# Name: name:Calum_Chambers, dtype: int32
# 0    0
# Name: name:Calvin_Ramsay, dtype: int32
# 0    0
# Name: name:Cameron_Archer, dtype: int32
# 0    0
# Name: name:Cameron_Peupion, dtype: int32
# 0    0
# Name: name:Cameron_Plain, dtype: int32
# 0    0
# Name: name:Caoimhin_Kelleher, dtype: int32
# 0    0
# Name: name:Carlos_Alcaraz, dtype: int32
# 0    0
# Name: name:Carlos_Henrique_Casimiro, dtype: int32
# 0    0
# Name: name:Carlos_Ribeiro_Dias, dtype: int32
# 0    0
# Name: name:Carlos_Vinícius_Alves_Morais, dtype: int32
# 0    0
# Name: name:Carney_Chukwuemeka, dtype: int32
# 0    0
# Name: name:Charlie_Goode, dtype: int32
# 0    0
# Name: name:Charlie_Robinson, dtype: int32
# 0    0
# Name: name:Che_Adams, dtype: int32
# 0    0
# Name: name:Cheick_Doucouré, dtype: int32
# 0    0
# Name: name:Cheikhou_Kouyaté, dtype: int32
# 0    0
# Name: name:Chem_Campbell, dtype: int32
# 0    0
# Name: name:Chris_Mepham, dtype: int32
# 0    0
# Name: name:Chris_Richards, dtype: int32
# 0    0
# Name: name:Chris_Wood, dtype: int32
# 0    0
# Name: name:Christian_Benteke, dtype: int32
# 0    0
# Name: name:Christian_Eriksen, dtype: int32
# 0    0
# Name: name:Christian_Nørgaard, dtype: int32
# 0    0
# Name: name:Christian_Pulisic, dtype: int32
# 0    0
# Name: name:Christian_Saydee, dtype: int32
# 0    0
# Name: name:Ciaran_Clark, dtype: int32
# 0    0
# Name: name:Claudio_Gomes, dtype: int32
# 0    0
# Name: name:Clément_Lenglet, dtype: int32
# 0    0
# Name: name:Cody_Drameh, dtype: int32
# 0    0
# Name: name:Cody_Gakpo, dtype: int32
# 0    0
# Name: name:Cole_Palmer, dtype: int32
# 0    0
# Name: name:Connor_Ronan, dtype: int32
# 0    0
# Name: name:Conor_Coady, dtype: int32
# 0    0
# Name: name:Conor_Coventry, dtype: int32
# 0    0
# Name: name:Conor_Gallagher, dtype: int32
# 0    0
# Name: name:Craig_Dawson, dtype: int32
# 0    0
# Name: name:Cristian_Romero, dtype: int32
# 0    0
# Name: name:Cristiano_Ronaldo_dos_Santos_Aveiro, dtype: int32
# 0    0
# Name: name:Crysencio_Summerville, dtype: int32
# 0    0
# Name: name:Curtis_Jones, dtype: int32
# 0    0
# Name: name:Cédric_Alves_Soares, dtype: int32
# 0    0
# Name: name:César_Azpilicueta, dtype: int32
# 0    0
# Name: name:Dale_Taylor, dtype: int32
# 0    0
# Name: name:Dan_Burn, dtype: int32
# 0    0
# Name: name:Dane_Scarlett, dtype: int32
# 0    0
# Name: name:Dango_Ouattara, dtype: int32
# 0    0
# Name: name:Daniel_Adu-Adjei, dtype: int32
# 0    0
# Name: name:Daniel_Amartey, dtype: int32
# 0    0
# Name: name:Daniel_Bentley, dtype: int32
# 0    0
# Name: name:Daniel_Castelo_Podence, dtype: int32
# 0    0
# Name: name:Daniel_Iversen, dtype: int32
# 0    0
# Name: name:Daniel_James, dtype: int32
# 0    0
# Name: name:Danilo_dos_Santos_de_Oliveira, dtype: int32
# 0    0
# Name: name:Danny_Ings, dtype: int32
# 0    0
# Name: name:Danny_Ward, dtype: int32
# 0    0
# Name: name:Danny_Welbeck, dtype: int32
# 0    0
# Name: name:Darko_Gyabi, dtype: int32
# 0    0
# Name: name:Darren_Randolph, dtype: int32
# 0    0
# Name: name:Darwin_Núñez_Ribeiro, dtype: int32
# 0    0
# Name: name:David_Brooks, dtype: int32
# 0    0
# Name: name:David_Datro_Fofana, dtype: int32
# 0    0
# Name: name:David_De_Gea_Quintana, dtype: int32
# 0    0
# Name: name:David_Ozoh, dtype: int32
# 0    0
# Name: name:David_Raya_Martin, dtype: int32
# 0    0
# Name: name:Davinson_Sánchez, dtype: int32
# 0    0
# Name: name:Dean_Henderson, dtype: int32
# 0    0
# Name: name:Declan_Rice, dtype: int32
# 0    0
# Name: name:Dejan_Kulusevski, dtype: int32
# 0    0
# Name: name:Dele_Alli, dtype: int32
# 0    0
# Name: name:Demarai_Gray, dtype: int32
# 0    0
# Name: name:Denis_Zakaria, dtype: int32
# 0    0
# Name: name:Deniz_Undav, dtype: int32
# 0    0
# Name: name:Dennis_Praet, dtype: int32
# 0    0
# Name: name:Dexter_Lembikisa, dtype: int32
# 0    0
# Name: name:Diego_Carlos_Santos_Silva, dtype: int32
# 0    0
# Name: name:Diego_Da_Silva_Costa, dtype: int32
# 0    0
# Name: name:Diego_Llorente, dtype: int32
# 0    0
# Name: name:Diogo_Dalot_Teixeira, dtype: int32
# 0    0
# Name: name:Diogo_Pinheiro_Monteiro, dtype: int32
# 0    0
# Name: name:Diogo_Teixeira_da_Silva, dtype: int32
# 0    0
# Name: name:Divin_Mubama, dtype: int32
# 0    0
# Name: name:Djed_Spence, dtype: int32
# 0    0
# Name: name:Dominic_Ballard, dtype: int32
# 0    0
# Name: name:Dominic_Calvert-Lewin, dtype: int32
# 0    0
# Name: name:Dominic_Sadi, dtype: int32
# 0    0
# Name: name:Dominic_Solanke, dtype: int32
# 0    0
# Name: name:Dominic_Thompson, dtype: int32
# 0    0
# Name: name:Donny_van_de_Beek, dtype: int32
# 0    0
# Name: name:Douglas_Luiz_Soares_de_Paulo, dtype: int32
# 0    0
# Name: name:Duje_Caleta-Car, dtype: int32
# 0    0
# Name: name:Dwight_Gayle, dtype: int32
# 0    0
# Name: name:Dwight_McNeil, dtype: int32
# 0    0
# Name: name:Eberechi_Eze, dtype: int32
# 0    0
# Name: name:Ed_Turns, dtype: int32
# 0    0
# Name: name:Eddie_Nketiah, dtype: int32
# 0    0
# Name: name:Ederson_Santana_de_Moraes, dtype: int32
# 0    0
# Name: name:Edouard_Mendy, dtype: int32
# 0    0
# Name: name:Eldin_Jakupovic, dtype: int32
# 0    0
# Name: name:Ellery_Balcombe, dtype: int32
# 0    0
# Name: name:Elliot_Anderson, dtype: int32
# 0    0
# Name: name:Ellis_Simms, dtype: int32
# 0    0
# Name: name:Emerson_Leite_de_Souza_Junior, dtype: int32
# 0    0
# Name: name:Emerson_Palmieri_dos_Santos, dtype: int32
# 0    0
# Name: name:Emil_Krafth, dtype: int32
# 0    0
# Name: name:Emile_Smith_Rowe, dtype: int32
# 0    0
# Name: name:Emiliano_Buendía_Stati, dtype: int32
# 0    0
# Name: name:Emiliano_Marcondes, dtype: int32
# 0    0
# Name: name:Emiliano_Martínez_Romero, dtype: int32
# 0    0
# Name: name:Emmanuel_Dennis, dtype: int32
# 0    0
# Name: name:Enock_Mwepu, dtype: int32
# 0    0
# Name: name:Enzo_Fernández, dtype: int32
# 0    0
# Name: name:Eric_Bailly, dtype: int32
# 0    0
# Name: name:Eric_Dier, dtype: int32
# 0    0
# Name: name:Erling_Haaland, dtype: int32
# 0    0
# Name: name:Ethan_Ampadu, dtype: int32
# 0    0
# Name: name:Ethan_Nwaneri, dtype: int32
# 0    0
# Name: name:Ethan_Pinnock, dtype: int32
# 0    0
# Name: name:Ethan_Wady, dtype: int32
# 0    0
# Name: name:Euan_Pollock, dtype: int32
# 0    0
# Name: name:Evan_Ferguson, dtype: int32
# 0    0
# Name: name:Ezri_Konsa_Ngoyo, dtype: int32
# 0    0
# Name: name:Fabian_Schär, dtype: int32
# 0    0
# Name: name:Fabio_Henrique_Tavares, dtype: int32
# 0    0
# Name: name:Fabio_Silva, dtype: int32
# 0    0
# Name: name:Facundo_Buonanotte, dtype: int32
# 0    0
# Name: name:Facundo_Pellistri_Rebollo, dtype: int32
# 0    0
# Name: name:Federico_Fernández, dtype: int32
# 0    0
# Name: name:Felipe_Augusto_de_Almeida_Monteiro, dtype: int32
# 0    0
# Name: name:Filip_Marschall, dtype: int32
# 0    0
# Name: name:Fin_Stevens, dtype: int32
# 0    0
# Name: name:Flynn_Downes, dtype: int32
# 0    0
# Name: name:Francisco_Jorge_Tomás_Oliveira, dtype: int32
# 0    0
# Name: name:Frank_Onyeka, dtype: int32
# 0    0
# Name: name:Fraser_Forster, dtype: int32
# 0    0
# Name: name:Frederico_Rodrigues_de_Paula_Santos, dtype: int32
# 0    0
# Name: name:Frédéric_Guilbert, dtype: int32
# 0    0
# Name: name:Fábio_Ferreira_Vieira, dtype: int32
# 0    0
# Name: name:Fábio_Freitas_Gouveia_Carvalho, dtype: int32
# 0    0
# Name: name:Gabriel_Fernando_de_Jesus, dtype: int32
# 0    0
# Name: name:Gabriel_Martinelli_Silva, dtype: int32
# 0    0
# Name: name:Gabriel_dos_Santos_Magalhães, dtype: int32
# 0    0
# Name: name:Garang_Kuol, dtype: int32
# 0    0
# Name: name:Gavin_Bazunu, dtype: int32
# 0    0
# Name: name:George_Abbott, dtype: int32
# 0    0
# Name: name:George_Shelvey, dtype: int32
# 0    0
# Name: name:George_Wickens, dtype: int32
# 0    0
# Name: name:Georginio_Rutter, dtype: int32
# 0    0
# Name: name:Gianluca_Scamacca, dtype: int32
# 0    0
# Name: name:Giulian_Biancone, dtype: int32
# 0    0
# Name: name:Gonçalo_Manuel_Ganchinho_Guedes, dtype: int32
# 0    0
# Name: name:Granit_Xhaka, dtype: int32
# 0    0
# Name: name:Gustavo_Henrique_Furtado_Scarpa, dtype: int32
# 0    0
# Name: name:Hakim_Ziyech, dtype: int32
# 0    0
# Name: name:Halil_Dervişoğlu, dtype: int32
# 0    0
# Name: name:Hamed_Traorè, dtype: int32
# 0    0
# Name: name:Hamza_Choudhury, dtype: int32
# 0    0
# Name: name:Harrison_Ashby, dtype: int32
# 0    0
# Name: name:Harrison_Reed, dtype: int32
# 0    0
# Name: name:Harry_Arter, dtype: int32
# 0    0
# Name: name:Harry_Kane, dtype: int32
# 0    0
# Name: name:Harry_Maguire, dtype: int32
# 0    0
# Name: name:Harry_Souttar, dtype: int32
# 0    0
# Name: name:Harry_Toffolo, dtype: int32
# 0    0
# Name: name:Harry_Wilson, dtype: int32
# 0    0
# Name: name:Harry_Winks, dtype: int32
# 0    0
# Name: name:Harvey_Barnes, dtype: int32
# 0    0
# Name: name:Harvey_Davies, dtype: int32
# 0    0
# Name: name:Harvey_Elliott, dtype: int32
# 0    0
# Name: name:Harvey_Griffiths, dtype: int32
# 0    0
# Name: name:Harvey_Vale, dtype: int32
# 0    0
# Name: name:Harvey_White, dtype: int32
# 0    0
# Name: name:Haydon_Roberts, dtype: int32
# 0    0
# Name: name:Hugo_Bueno_López, dtype: int32
# 0    0
# Name: name:Hugo_Lloris, dtype: int32
# 0    0
# Name: name:Hwang_Hee-chan, dtype: int32
# 0    0
# Name: name:Ibrahima_Diallo, dtype: int32
# 0    0
# Name: name:Ibrahima_Konaté, dtype: int32
# 0    0
# Name: name:Idrissa_Gueye, dtype: int32
# 0    0
# Name: name:Ilkay_Gündogan, dtype: int32
# 0    0
# Name: name:Illan_Meslier, dtype: int32
# 0    0
# Name: name:Illia_Zabarnyi, dtype: int32
# 0    0
# Name: name:Imari_Samuels, dtype: int32
# 0    0
# Name: name:Isaac_Price, dtype: int32
# 0    0
# Name: name:Ishé_Samuels-Smith, dtype: int32
# 0    0
# Name: name:Issa_Diop, dtype: int32
# 0    0
# Name: name:Ivan_Neves_Abreu_Cavaleiro, dtype: int32
# 0    0
# Name: name:Ivan_Perišić, dtype: int32
# 0    0
# Name: name:Ivan_Toney, dtype: int32
# 0    0
# Name: name:Jack_Butland, dtype: int32
# 0    0
# Name: name:Jack_Colback, dtype: int32
# 0    0
# Name: name:Jack_Grealish, dtype: int32
# 0    0
# Name: name:Jack_Harrison, dtype: int32
# 0    0
# Name: name:Jack_Hinshelwood, dtype: int32
# 0    0
# Name: name:Jack_Stacey, dtype: int32
# 0    0
# Name: name:Jack_Stephens, dtype: int32
# 0    0
# Name: name:Jack_Wells-Morrison, dtype: int32
# 0    0
# Name: name:Jackson_Smith, dtype: int32
# 0    0
# Name: name:Jacob_Murphy, dtype: int32
# 0    0
# Name: name:Jacob_Ramsey, dtype: int32
# 0    0
# Name: name:Jaden_Philogene-Bidace, dtype: int32
# 0    0
# Name: name:Jadon_Sancho, dtype: int32
# 0    0
# Name: name:Jaidon_Anthony, dtype: int32
# 0    0
# Name: name:Jairo_Riedewald, dtype: int32
# 0    0
# Name: name:Jakub_Kiwior, dtype: int32
# 0    0
# Name: name:Jakub_Moder, dtype: int32
# 0    0
# Name: name:Jamaal_Lascelles, dtype: int32
# 0    0
# Name: name:Jamal_Lewis, dtype: int32
# 0    0
# Name: name:Jamal_Lowe, dtype: int32
# 0    0
# Name: name:James_Bree, dtype: int32
# 0    0
# Name: name:James_Furlong, dtype: int32
# 0    0
# Name: name:James_Garner, dtype: int32
# 0    0
# Name: name:James_Hill, dtype: int32
# 0    0
# Name: name:James_Justin, dtype: int32
# 0    0
# Name: name:James_Maddison, dtype: int32
# 0    0
# Name: name:James_McArthur, dtype: int32
# 0    0
# Name: name:James_McAtee, dtype: int32
# 0    0
# Name: name:James_Milner, dtype: int32
# 0    0
# Name: name:James_Tarkowski, dtype: int32
# 0    0
# Name: name:James_Tomkins, dtype: int32
# 0    0
# Name: name:James_Ward-Prowse, dtype: int32
# 0    0
# Name: name:James_Wright, dtype: int32
# 0    0
# Name: name:Jamie_Shackleton, dtype: int32
# 0    0
# Name: name:Jamie_Vardy, dtype: int32
# 0    0
# Name: name:Jan_Bednarek, dtype: int32
# 0    0
# Name: name:Jan_Paul_van_Hecke, dtype: int32
# 0    0
# Name: name:Jannik_Vestergaard, dtype: int32
# 0    0
# Name: name:Japhet_Tanganga, dtype: int32
# 0    0
# Name: name:Jarrad_Branthwaite, dtype: int32
# 0    0
# Name: name:Jarrod_Bowen, dtype: int32
# 0    0
# Name: name:Jason_Steele, dtype: int32
# 0    0
# Name: name:Javier_Manquillo_Gaitán, dtype: int32
# 0    0
# Name: name:Jay_Stansfield, dtype: int32
# 0    0
# Name: name:Jean-Philippe_Gbamin, dtype: int32
# 0    0
# Name: name:Jean-Philippe_Mateta, dtype: int32
# 0    0
# Name: name:Jeff_Hendrick, dtype: int32
# 0    0
# Name: name:Jefferson_Lerma_Solís, dtype: int32
# 0    0
# Name: name:Jeffrey_Schlupp, dtype: int32
# 0    0
# Name: name:Jeremiah_Chilokoa-Mullen, dtype: int32
# 0    0
# Name: name:Jeremy_Sarmiento_Morante, dtype: int32
# 0    0
# Name: name:Jesse_Lingard, dtype: int32
# 0    0
# Name: name:Jesurun_Rak-Sakyi, dtype: int32
# 0    0
# Name: name:Jhon_Durán, dtype: int32
# 0    0
# Name: name:Jimmy_Morgan, dtype: int32
# 0    0
# Name: name:Joachim_Andersen, dtype: int32
# 0    0
# Name: name:Joe_Ayodele-Aribo, dtype: int32
# 0    0
# Name: name:Joe_Bryan, dtype: int32
# 0    0
# Name: name:Joe_Gelhardt, dtype: int32
# 0    0
# Name: name:Joe_Lolley, dtype: int32
# 0    0
# Name: name:Joe_Rodon, dtype: int32
# 0    0
# Name: name:Joe_Rothwell, dtype: int32
# 0    0
# Name: name:Joe_Willock, dtype: int32
# 0    0
# Name: name:Joe_Wormleighton, dtype: int32
# 0    0
# Name: name:Joe_Worrall, dtype: int32
# 0    0
# Name: name:Joel_Matip, dtype: int32
# 0    0
# Name: name:Joel_Robles, dtype: int32
# 0    0
# Name: name:Joel_Ward, dtype: int32
# 0    0
# Name: name:Joelinton_Cássio_Apolinário_de_Lira, dtype: int32
# 0    0
# Name: name:John-Kymani_Gordon, dtype: int32
# 0    0
# Name: name:John_McGinn, dtype: int32
# 0    0
# Name: name:John_Stones, dtype: int32
# 0    0
# Name: name:Jonathan_Castro_Otto, dtype: int32
# 0    0
# Name: name:Jonathan_Panzo, dtype: int32
# 0    0
# Name: name:Jonjo_Shelvey, dtype: int32
# 0    0
# Name: name:Jonny_Evans, dtype: int32
# 0    0
# Name: name:Jordan_Ayew, dtype: int32
# 0    0
# Name: name:Jordan_Henderson, dtype: int32
# 0    0
# Name: name:Jordan_Pickford, dtype: int32
# 0    0
# Name: name:Jordan_Smith, dtype: int32
# 0    0
# Name: name:Jordan_Zemura, dtype: int32
# 0    0
# Name: name:Jorge_Luiz_Frello_Filho, dtype: int32
# 0    0
# Name: name:Joseph_Anang, dtype: int32
# 0    0
# Name: name:Joseph_Gomez, dtype: int32
# 0    0
# Name: name:Joseph_Hodge, dtype: int32
# 0    0
# Name: name:Joseph_Whitworth, dtype: int32
# 0    0
# Name: name:Josh_Dasilva, dtype: int32
# 0    0
# Name: name:Josh_Onomah, dtype: int32
# 0    0
# Name: name:Josh_Wilson-Esbrand, dtype: int32
# 0    0
# Name: name:José_Malheiro_de_Sá, dtype: int32
# 0    0
# Name: name:João_Cancelo, dtype: int32
# 0    0
# Name: name:João_Filipe_Iria_Santos_Moutinho, dtype: int32
# 0    0
# Name: name:João_Félix_Sequeira, dtype: int32
# 0    0
# Name: name:João_Palhinha_Gonçalves, dtype: int32
# 0    0
# Name: name:João_Victor_Gomes_da_Silva, dtype: int32
# 0    0
# Name: name:Joël_Veltman, dtype: int32
# 0    0
# Name: name:Juan_Larios_López, dtype: int32
# 0    0
# Name: name:Julio_Enciso, dtype: int32
# 0    0
# Name: name:Julián_Álvarez, dtype: int32
# 0    0
# Name: name:Junior_Firpo_Adames, dtype: int32
# 0    0
# Name: name:Junior_Stanislas, dtype: int32
# 0    0
# Name: name:Kacper_Kozłowski, dtype: int32
# 0    0
# Name: name:Kadan_Young, dtype: int32
# 0    0
# Name: name:Kaden_Rodney, dtype: int32
# 0    0
# Name: name:Kaelan_Casey, dtype: int32
# 0    0
# Name: name:Kai_Havertz, dtype: int32
# 0    0
# Name: name:Kaine_Kesler_Hayden, dtype: int32
# 0    0
# Name: name:Kalidou_Koulibaly, dtype: int32
# 0    0
# Name: name:Kalvin_Phillips, dtype: int32
# 0    0
# Name: name:Kamaldeen_Sulemana, dtype: int32
# 0    0
# Name: name:Kamari_Doyle, dtype: int32
# 0    0
# Name: name:Kaoru_Mitoma, dtype: int32
# 0    0
# Name: name:Karl_Darlow, dtype: int32
# 0    0
# Name: name:Karl_Hein, dtype: int32
# 0    0
# Name: name:Kasey_McAteer, dtype: int32
# 0    0
# Name: name:Kasper_Schmeichel, dtype: int32
# 0    0
# Name: name:Keane_Lewis-Potter, dtype: int32
# 0    0
# Name: name:Keinan_Davis, dtype: int32
# 0    0
# Name: name:Kelechi_Iheanacho, dtype: int32
# 0    0
# Name: name:Kenny_Tete, dtype: int32
# 0    0
# Name: name:Kepa_Arrizabalaga, dtype: int32
# 0    0
# Name: name:Kevin_De_Bruyne, dtype: int32
# 0    0
# Name: name:Kevin_Mbabu, dtype: int32
# 0    0
# Name: name:Kevin_Schade, dtype: int32
# 0    0
# Name: name:Keylor_Navas, dtype: int32
# 0    0
# Name: name:Kieffer_Moore, dtype: int32
# 0    0
# Name: name:Kieran_Tierney, dtype: int32
# 0    0
# Name: name:Kieran_Trippier, dtype: int32
# 0    0
# Name: name:Kiernan_Dewsbury-Hall, dtype: int32
# 0    0
# Name: name:Killian_Phillips, dtype: int32
# 0    0
# Name: name:Kjell_Scherpen, dtype: int32
# 0    0
# Name: name:Kobbie_Mainoo, dtype: int32
# 0    0
# Name: name:Kofi_Balmer, dtype: int32
# 0    0
# Name: name:Konstantinos_Tsimikas, dtype: int32
# 0    0
# Name: name:Kortney_Hause, dtype: int32
# 0    0
# Name: name:Kristian_Sekularac, dtype: int32
# 0    0
# Name: name:Kristoffer_Ajer, dtype: int32
# 0    0
# Name: name:Kristoffer_Klaesson, dtype: int32
# 0    0
# Name: name:Krisztián_Hegyi, dtype: int32
# 0    0
# Name: name:Kurt_Zouma, dtype: int32
# 0    0
# Name: name:Kyle_John, dtype: int32
# 0    0
# Name: name:Kyle_Walker, dtype: int32
# 0    0
# Name: name:Kyle_Walker-Peters, dtype: int32
# 0    0
# Name: name:Lamare_Bogarde, dtype: int32
# 0    0
# Name: name:Layvin_Kurzawa, dtype: int32
# 0    0
# Name: name:Leander_Dendoncker, dtype: int32
# 0    0
# Name: name:Leandro_Trossard, dtype: int32
# 0    0
# Name: name:Leo_Fuhr_Hjelde, dtype: int32
# 0    0
# Name: name:Leon_Bailey, dtype: int32
# 0    0
# Name: name:Levi_Colwill, dtype: int32
# 0    0
# Name: name:Lewis_Bate, dtype: int32
# 0    0
# Name: name:Lewis_Brunt, dtype: int32
# 0    0
# Name: name:Lewis_Cook, dtype: int32
# 0    0
# Name: name:Lewis_Dunk, dtype: int32
# 0    0
# Name: name:Lewis_Hall, dtype: int32
# 0    0
# Name: name:Lewis_Miley, dtype: int32
# 0    0
# Name: name:Lewis_O'Brien, dtype: int32
# 0    0
# Name: name:Lewis_Payne, dtype: int32
# 0    0
# Name: name:Lewis_Warrington, dtype: int32
# 0    0
# Name: name:Liam_Cooper, dtype: int32
# 0    0
# Name: name:Liam_Delap, dtype: int32
# 0    0
# Name: name:Lino_Sousa, dtype: int32
# 0    0
# Name: name:Lisandro_Martínez, dtype: int32
# 0    0
# Name: name:Lloyd_Kelly, dtype: int32
# 0    0
# Name: name:Loris_Karius, dtype: int32
# 0    0
# Name: name:Loïc_Badé, dtype: int32
# 0    0
# Name: name:Loïc_Mbe_Soh, dtype: int32
# 0    0
# Name: name:Lucas_Digne, dtype: int32
# 0    0
# Name: name:Lucas_Rodrigues_Moura_da_Silva, dtype: int32
# 0    0
# Name: name:Lucas_Tolentino_Coelho_de_Lima, dtype: int32
# 0    0
# Name: name:Lucas_Torreira_di_Pascua, dtype: int32
# 0    0
# Name: name:Ludwig_Augustinsson, dtype: int32
# 0    0
# Name: name:Luis_Díaz, dtype: int32
# 0    0
# Name: name:Luis_Sinisterra_Lucumí, dtype: int32
# 0    0
# Name: name:Luka_Milivojevic, dtype: int32
# 0    0
# Name: name:Lukasz_Fabianski, dtype: int32
# 0    0
# Name: name:Luke_Ayling, dtype: int32
# 0    0
# Name: name:Luke_Chambers, dtype: int32
# 0    0
# Name: name:Luke_Cundle, dtype: int32
# 0    0
# Name: name:Luke_Harris, dtype: int32
# 0    0
# Name: name:Luke_Mbete-Tabu, dtype: int32
# 0    0
# Name: name:Luke_Plange, dtype: int32
# 0    0
# Name: name:Luke_Shaw, dtype: int32
# 0    0
# Name: name:Luke_Thomas, dtype: int32
# 0    0
# Name: name:Lyanco_Silveira_Neves_Vojnovic, dtype: int32
# 0    0
# Name: name:Lyle_Taylor, dtype: int32
# 0    0
# Name: name:Mads_Bech_Sørensen, dtype: int32
# 0    0
# Name: name:Mads_Bidstrup, dtype: int32
# 0    0
# Name: name:Mads_Roerslev_Rasmussen, dtype: int32
# 0    0
# Name: name:Malang_Sarr, dtype: int32
# 0    0
# Name: name:Malcolm_Ebiowei, dtype: int32
# 0    0
# Name: name:Manor_Solomon, dtype: int32
# 0    0
# Name: name:Manuel_Akanji, dtype: int32
# 0    0
# Name: name:Manuel_Lanzini, dtype: int32
# 0    0
# Name: name:Marc_Albrighton, dtype: int32
# 0    0
# Name: name:Marc_Cucurella_Saseta, dtype: int32
# 0    0
# Name: name:Marc_Guéhi, dtype: int32
# 0    0
# Name: name:Marc_Jurado_Gomez, dtype: int32
# 0    0
# Name: name:Marc_Roca_Junqué, dtype: int32
# 0    0
# Name: name:Marcel_Sabitzer, dtype: int32
# 0    0
# Name: name:Marcos_Alonso, dtype: int32
# 0    0
# Name: name:Marcos_Senesi, dtype: int32
# 0    0
# Name: name:Marcus_Bettinelli, dtype: int32
# 0    0
# Name: name:Marcus_Forss, dtype: int32
# 0    0
# Name: name:Marcus_Oliveira_Alencar, dtype: int32
# 0    0
# Name: name:Marcus_Rashford, dtype: int32
# 0    0
# Name: name:Marcus_Tavernier, dtype: int32
# 0    0
# Name: name:Marek_Rodák, dtype: int32
# 0    0
# Name: name:Mario_Lemina, dtype: int32
# 0    0
# Name: name:Mark_Gillespie, dtype: int32
# 0    0
# Name: name:Mark_Travers, dtype: int32
# 0    0
# Name: name:Martial_Godo, dtype: int32
# 0    0
# Name: name:Martin_Dubravka, dtype: int32
# 0    0
# Name: name:Martin_Ødegaard, dtype: int32
# 0    0
# Name: name:Marvelous_Nakamba, dtype: int32
# 0    0
# Name: name:Mason_Holgate, dtype: int32
# 0    0
# Name: name:Mason_Mount, dtype: int32
# 0    0
# Name: name:Matej_Kovár, dtype: int32
# 0    0
# Name: name:Mateo_Joseph_Fernández, dtype: int32
# 0    0
# Name: name:Mateo_Kovacic, dtype: int32
# 0    0
# Name: name:Mateus_Cardoso_Lemos_Martins, dtype: int32
# 0    0
# Name: name:Mateusz_Klich, dtype: int32
# 0    0
# Name: name:Mateusz_Lis, dtype: int32
# 0    0
# Name: name:Matheus_Luiz_Nunes, dtype: int32
# 0    0
# Name: name:Matheus_Santos_Carneiro_Da_Cunha, dtype: int32
# 0    0
# Name: name:Mathias_Jensen, dtype: int32
# 0    0
# Name: name:Mathias_Jorgensen, dtype: int32
# 0    0
# Name: name:Matija_Šarkić, dtype: int32
# 0    0
# Name: name:Matt_Clarke, dtype: int32
# 0    0
# Name: name:Matt_Doherty, dtype: int32
# 0    0
# Name: name:Matt_Ritchie, dtype: int32
# 0    0
# Name: name:Matt_Targett, dtype: int32
# 0    0
# Name: name:Matt_Turner, dtype: int32
# 0    0
# Name: name:Matthew_Cox, dtype: int32
# 0    0
# Name: name:Matthew_Craig, dtype: int32
# 0    0
# Name: name:Matthew_Dibley-Dias, dtype: int32
# 0    0
# Name: name:Matthew_Smith, dtype: int32
# 0    0
# Name: name:Matty_Cash, dtype: int32
# 0    0
# Name: name:Matías_Viña, dtype: int32
# 0    0
# Name: name:Mauro_Bandeira, dtype: int32
# 0    0
# Name: name:Max_Kilman, dtype: int32
# 0    0
# Name: name:Max_Kinsey-Wellings, dtype: int32
# 0    0
# Name: name:Maximilian_Wöber, dtype: int32
# 0    0
# Name: name:Maxwel_Cornet, dtype: int32
# 0    0
# Name: name:Michael_Dacosta_Gonzalez, dtype: int32
# 0    0
# Name: name:Michael_Keane, dtype: int32
# 0    0
# Name: name:Michael_Olakigbe, dtype: int32
# 0    0
# Name: name:Michael_Olise, dtype: int32
# 0    0
# Name: name:Michail_Antonio, dtype: int32
# 0    0
# Name: name:Miguel_Almirón_Rejala, dtype: int32
# 0    0
# Name: name:Mikkel_Damsgaard, dtype: int32
# 0    0
# Name: name:Mislav_Orsic, dtype: int32
# 0    0
# Name: name:Mohamed_Dräger, dtype: int32
# 0    0
# Name: name:Mohamed_Elneny, dtype: int32
# 0    0
# Name: name:Mohamed_Elyounoussi, dtype: int32
# 0    0
# Name: name:Mohamed_Salah, dtype: int32
# 0    0
# Name: name:Mohammed_Salisu, dtype: int32
# 0    0
# Name: name:Moisés_Caicedo_Corozo, dtype: int32
# 0    0
# Name: name:Morgan_Gibbs-White, dtype: int32
# 0    0
# Name: name:Morgan_Sanson, dtype: int32
# 0    0
# Name: name:Moussa_Djenepo, dtype: int32
# 0    0
# Name: name:Moussa_Niakhaté, dtype: int32
# 0    0
# Name: name:Mykhailo_Mudryk, dtype: int32
# 0    0
# Name: name:Máximo_Perrone, dtype: int32
# 0    0
# Name: name:N'Golo_Kanté, dtype: int32
# 0    0
# Name: name:Naby_Keita, dtype: int32
# 0    0
# Name: name:Nampalys_Mendy, dtype: int32
# 0    0
# Name: name:Naouirou_Ahamada, dtype: int32
# 0    0
# Name: name:Nathan_Aké, dtype: int32
# 0    0
# Name: name:Nathan_Bishop, dtype: int32
# 0    0
# Name: name:Nathan_Butler-Oyedeji, dtype: int32
# 0    0
# Name: name:Nathan_Collins, dtype: int32
# 0    0
# Name: name:Nathan_Ferguson, dtype: int32
# 0    0
# Name: name:Nathan_Fraser, dtype: int32
# 0    0
# Name: name:Nathan_Patterson, dtype: int32
# 0    1
# Name: name:Nathan_Redmond, dtype: int32
# 0    0
# Name: name:Nathan_Tella, dtype: int32
# 0    0
# Name: name:Nathaniel_Chalobah, dtype: int32
# 0    0
# Name: name:Nathaniel_Clyne, dtype: int32
# 0    0
# Name: name:Nathaniel_Phillips, dtype: int32
# 0    0
# Name: name:Nayef_Aguerd, dtype: int32
# 0    0
# Name: name:Neal_Maupay, dtype: int32
# 0    0
# Name: name:Neco_Williams, dtype: int32
# 0    0
# Name: name:Neeskens_Kebano, dtype: int32
# 0    0
# Name: name:Nick_Pope, dtype: int32
# 0    0
# Name: name:Nico_O'Reilly, dtype: int32
# 0    0
# Name: name:Nicolas_Pépé, dtype: int32
# 0    0
# Name: name:Niels_Nkounkou, dtype: int32
# 0    0
# Name: name:Nikola_Vlasic, dtype: int32
# 0    0
# Name: name:Noni_Madueke, dtype: int32
# 0    0
# Name: name:Norberto_Murara_Neto, dtype: int32
# 0    0
# Name: name:Nuno_Varela_Tavares, dtype: int32
# 0    0
# Name: name:Nélson_Cabral_Semedo, dtype: int32
# 0    0
# Name: name:Odeluga_Offiah, dtype: int32
# 0    0
# Name: name:Odsonne_Edouard, dtype: int32
# 0    0
# Name: name:Oleksandr_Zinchenko, dtype: int32
# 0    0
# Name: name:Oliver_Hammond, dtype: int32
# 0    0
# Name: name:Oliver_Skipp, dtype: int32
# 0    0
# Name: name:Oliwier_Zych, dtype: int32
# 0    0
# Name: name:Ollie_Watkins, dtype: int32
# 0    0
# Name: name:Omar_Richards, dtype: int32
# 0    0
# Name: name:Omari_Hutchinson, dtype: int32
# 0    0
# Name: name:Orel_Mangala, dtype: int32
# 0    0
# Name: name:Oriol_Romeu_Vidal, dtype: int32
# 0    0
# Name: name:Owen_Bevan, dtype: int32
# 0    0
# Name: name:Owen_Goodman, dtype: int32
# 0    0
# Name: name:Pablo_Fornals_Malla, dtype: int32
# 0    0
# Name: name:Pablo_Marí_Villar, dtype: int32
# 0    0
# Name: name:Pablo_Sarabia, dtype: int32
# 0    0
# Name: name:Pape_Matar_Sarr, dtype: int32
# 0    0
# Name: name:Pascal_Groß, dtype: int32
# 0    0
# Name: name:Pascal_Struijk, dtype: int32
# 0    0
# Name: name:Patrick_Bamford, dtype: int32
# 0    0
# Name: name:Patson_Daka, dtype: int32
# 0    0
# Name: name:Paul_Dummett, dtype: int32
# 0    0
# Name: name:Paul_Onuachu, dtype: int32
# 0    0
# Name: name:Paulo_Gazzaniga_Farias, dtype: int32
# 0    0
# Name: name:Pedro_Lomba_Neto, dtype: int32
# 0    0
# Name: name:Pedro_Porro, dtype: int32
# 0    0
# Name: name:Pervis_Estupiñán, dtype: int32
# 0    0
# Name: name:Phil_Foden, dtype: int32
# 0    0
# Name: name:Phil_Jones, dtype: int32
# 0    0
# Name: name:Philip_Billing, dtype: int32
# 0    0
# Name: name:Philippe_Coutinho_Correia, dtype: int32
# 0    0
# Name: name:Pierre-Emerick_Aubameyang, dtype: int32
# 0    0
# Name: name:Pierre-Emile_Højbjerg, dtype: int32
# 0    0
# Name: name:Pontus_Jansson, dtype: int32
# 0    0
# Name: name:Raheem_Sterling, dtype: int32
# 0    0
# Name: name:Raphael_Dias_Belloli, dtype: int32
# 0    0
# Name: name:Raphaël_Varane, dtype: int32
# 0    0
# Name: name:Rasmus_Kristensen, dtype: int32
# 0    0
# Name: name:Rayan_Aït-Nouri, dtype: int32
# 0    0
# Name: name:Raúl_Jiménez, dtype: int32
# 0    0
# Name: name:Reece_James, dtype: int32
# 0    0
# Name: name:Reece_Welch, dtype: int32
# 0    0
# Name: name:Reiss_Nelson, dtype: int32
# 0    0
# Name: name:Remi_Matthews, dtype: int32
# 0    0
# Name: name:Remo_Freuler, dtype: int32
# 0    0
# Name: name:Renan_Augusto_Lodi_dos_Santos, dtype: int32
# 0    0
# Name: name:Reuell_Walters, dtype: int32
# 0    0
# Name: name:Rhys_Bennett, dtype: int32
# 0    0
# Name: name:Rhys_Williams, dtype: int32
# 0    0
# Name: name:Ricardo_Barbosa_Pereira, dtype: int32
# 0    0
# Name: name:Richarlison_de_Andrade, dtype: int32
# 0    0
# Name: name:Richie_Laryea, dtype: int32
# 0    0
# Name: name:Rico_Henry, dtype: int32
# 0    0
# Name: name:Rico_Lewis, dtype: int32
# 0    0
# Name: name:Riyad_Mahrez, dtype: int32
# 0    0
# Name: name:Rob_Holding, dtype: int32
# 0    0
# Name: name:Robert_Kenedy_Nunes_do_Nascimento, dtype: int32
# 0    0
# Name: name:Robert_Sánchez, dtype: int32
# 0    0
# Name: name:Roberto_Firmino, dtype: int32
# 0    0
# Name: name:Robin_Koch, dtype: int32
# 0    0
# Name: name:Robin_Olsen, dtype: int32
# 0    0
# Name: name:Rodrigo_Bentancur, dtype: int32
# 0    0
# Name: name:Rodrigo_Hernandez, dtype: int32
# 0    0
# Name: name:Rodrigo_Moreno, dtype: int32
# 0    0
# Name: name:Rodrigo_Muniz_Carvalho, dtype: int32
# 0    0
# Name: name:Romain_Perraud, dtype: int32
# 0    0
# Name: name:Romaine_Mundle, dtype: int32
# 0    0
# Name: name:Roméo_Lavia, dtype: int32
# 0    0
# Name: name:Ross_Barkley, dtype: int32
# 0    0
# Name: name:Ruben_Loftus-Cheek, dtype: int32
# 0    0
# Name: name:Ryan_Bertrand, dtype: int32
# 0    0
# Name: name:Ryan_Christie, dtype: int32
# 0    0
# Name: name:Ryan_Finnigan, dtype: int32
# 0    0
# Name: name:Ryan_Fraser, dtype: int32
# 0    0
# Name: name:Ryan_Fredericks, dtype: int32
# 0    0
# Name: name:Ryan_Sessegnon, dtype: int32
# 0    0
# Name: name:Ryan_Trevitt, dtype: int32
# 0    0
# Name: name:Ryan_Yates, dtype: int32
# 0    0
# Name: name:Rúben_Gato_Alves_Dias, dtype: int32
# 0    0
# Name: name:Rúben_Nascimento_Vinagre, dtype: int32
# 0    0
# Name: name:Rúben_da_Silva_Neves, dtype: int32
# 0    0
# Name: name:Salomón_Rondón, dtype: int32
# 0    0
# Name: name:Sam_Greenwood, dtype: int32
# 0    0
# Name: name:Sam_Johnstone, dtype: int32
# 0    0
# Name: name:Sam_Surridge, dtype: int32
# 0    0
# Name: name:Saman_Ghoddos, dtype: int32
# 0    0
# Name: name:Sammy_Braybrooke, dtype: int32
# 0    0
# Name: name:Samuel_Amo-Ameyaw, dtype: int32
# 0    0
# Name: name:Samuel_Edozie, dtype: int32
# 0    0
# Name: name:Sasa_Kalajdzic, dtype: int32
# 0    0
# Name: name:Sasa_Lukic, dtype: int32
# 0    0
# Name: name:Saïd_Benrahma, dtype: int32
# 0    0
# Name: name:Scott_Carson, dtype: int32
# 0    0
# Name: name:Scott_McKenna, dtype: int32
# 0    0
# Name: name:Scott_McTominay, dtype: int32
# 0    0
# Name: name:Seamus_Coleman, dtype: int32
# 0    0
# Name: name:Sean_Longstaff, dtype: int32
# 0    0
# Name: name:Sean_McAllister, dtype: int32
# 0    0
# Name: name:Sebastian_Revan, dtype: int32
# 0    0
# Name: name:Sepp_van_den_Berg, dtype: int32
# 0    0
# Name: name:Serge_Aurier, dtype: int32
# 0    0
# Name: name:Sergi_Canós_Tenés, dtype: int32
# 0    0
# Name: name:Sergio_Gómez, dtype: int32
# 0    0
# Name: name:Sergio_Reguilón, dtype: int32
# 0    0
# Name: name:Shandon_Baptiste, dtype: int32
# 0    0
# Name: name:Shane_Duffy, dtype: int32
# 0    0
# Name: name:Shea_Charles, dtype: int32
# 0    0
# Name: name:Shola_Shoretire, dtype: int32
# 0    0
# Name: name:Sil_Swinkels, dtype: int32
# 0    0
# Name: name:Siriki_Dembélé, dtype: int32
# 0    0
# Name: name:Solly_March, dtype: int32
# 0    0
# Name: name:Son_Heung-min, dtype: int32
# 0    0
# Name: name:Sonny_Perkins, dtype: int32
# 0    0
# Name: name:Stanley_Mills, dtype: int32
# 0    0
# Name: name:Stefan_Bajcetic, dtype: int32
# 0    0
# Name: name:Stefan_Ortega_Moreno, dtype: int32
# 0    0
# Name: name:Stefan_Parkes, dtype: int32
# 0    0
# Name: name:Steve_Cook, dtype: int32
# 0    0
# Name: name:Steven_Alzate, dtype: int32
# 0    0
# Name: name:Steven_Bergwijn, dtype: int32
# 0    0
# Name: name:Stuart_Armstrong, dtype: int32
# 0    0
# Name: name:Stuart_Dallas, dtype: int32
# 0    0
# Name: name:Sven_Botman, dtype: int32
# 0    0
# Name: name:Sékou_Mara, dtype: int32
# 0    0
# Name: name:Taiwo_Awoniyi, dtype: int32
# 0    0
# Name: name:Takehiro_Tomiyasu, dtype: int32
# 0    0
# Name: name:Tariq_Lamptey, dtype: int32
# 0    0
# Name: name:Taylor_Richards, dtype: int32
# 0    0
# Name: name:Tayo_Adaramola, dtype: int32
# 0    0
# Name: name:Terence_Kongolo, dtype: int32
# 0    0
# Name: name:Terry_Ablade, dtype: int32
# 0    0
# Name: name:Theo_Walcott, dtype: int32
# 0    0
# Name: name:Thiago_Alcántara_do_Nascimento, dtype: int32
# 0    0
# Name: name:Thiago_Emiliano_da_Silva, dtype: int32
# 0    0
# Name: name:Thilo_Kehrer, dtype: int32
# 0    0
# Name: name:Thomas_Cannon, dtype: int32
# 0    0
# Name: name:Thomas_Partey, dtype: int32
# 0    0
# Name: name:Thomas_Strakosha, dtype: int32
# 0    0
# Name: name:Tim_Iroegbunam, dtype: int32
# 0    0
# Name: name:Tim_Ream, dtype: int32
# 0    0
# Name: name:Timo_Werner, dtype: int32
# 0    0
# Name: name:Timothy_Castagne, dtype: int32
# 0    0
# Name: name:Tino_Livramento, dtype: int32
# 0    0
# Name: name:Tom_Cairney, dtype: int32
# 0    0
# Name: name:Tom_Davies, dtype: int32
# 0    0
# Name: name:Tom_Heaton, dtype: int32
# 0    0
# Name: name:Tom_McGill, dtype: int32
# 0    0
# Name: name:Tomas_Soucek, dtype: int32
# 0    0
# Name: name:Tommi_O'Reilly, dtype: int32
# 0    0
# Name: name:Tosin_Adarabioyo, dtype: int32
# 0    0
# Name: name:Toti_António_Gomes, dtype: int32
# 0    0
# Name: name:Travis_Patterson, dtype: int32
# 0    0
# Name: name:Trent_Alexander-Arnold, dtype: int32
# 0    0
# Name: name:Trevoh_Chalobah, dtype: int32
# 0    0
# Name: name:Tristan_Crama, dtype: int32
# 0    0
# Name: name:Troy_Parrott, dtype: int32
# 0    0
# Name: name:Tyler_Adams, dtype: int32
# 0    0
# Name: name:Tyler_Roberts, dtype: int32
# 0    0
# Name: name:Tyrell_Malacia, dtype: int32
# 0    0
# Name: name:Tyrese_Francois, dtype: int32
# 0    0
# Name: name:Tyrick_Mitchell, dtype: int32
# 0    0
# Name: name:Tyrone_Mings, dtype: int32
# 0    0
# Name: name:Vicente_Guaita, dtype: int32
# 0    0
# Name: name:Victor_Kristiansen, dtype: int32
# 0    0
# Name: name:Victor_Lindelöf, dtype: int32
# 0    0
# Name: name:Viljami_Sinisalo, dtype: int32
# 0    0
# Name: name:Virgil_van_Dijk, dtype: int32
# 0    0
# Name: name:Vitalii_Mykolenko, dtype: int32
# 0    0
# Name: name:Vitaly_Janelt, dtype: int32
# 0    0
# Name: name:Vladimir_Coufal, dtype: int32
# 0    0
# Name: name:Wanya_Marçal-Madivadua, dtype: int32
# 0    0
# Name: name:Wayne_Hennessey, dtype: int32
# 0    0
# Name: name:Wesley_Fofana, dtype: int32
# 0    0
# Name: name:Weston_McKennie, dtype: int32
# 0    0
# Name: name:Wilfred_Ndidi, dtype: int32
# 0    0
# Name: name:Wilfried_Gnonto, dtype: int32
# 0    0
# Name: name:Wilfried_Zaha, dtype: int32
# 0    0
# Name: name:Will_Dennis, dtype: int32
# 0    0
# Name: name:Will_Hughes, dtype: int32
# 0    0
# Name: name:Will_Smallbone, dtype: int32
# 0    0
# Name: name:William_Saliba, dtype: int32
# 0    0
# Name: name:Willian_Borges_da_Silva, dtype: int32
# 0    0
# Name: name:Willy_Boly, dtype: int32
# 0    0
# Name: name:Willy_Caballero, dtype: int32
# 0    0
# Name: name:Wout_Faes, dtype: int32
# 0    0
# Name: name:Wout_Weghorst, dtype: int32
# 0    0
# Name: name:Xande_Nascimento_da_Costa_Silva, dtype: int32
# 0    0
# Name: name:Yago_de_Santiago_Alonso, dtype: int32
# 0    0
# Name: name:Yan_Valery, dtype: int32
# 0    0
# Name: name:Yasin_Ayari, dtype: int32
# 0    0
# Name: name:Yegor_Yarmolyuk, dtype: int32
# 0    0
# Name: name:Yerry_Mina, dtype: int32
# 0    0
# Name: name:Yerson_Mosquera_Valdelamar, dtype: int32
# 0    0
# Name: name:Yoane_Wissa, dtype: int32
# 0    0
# Name: name:Youri_Tielemans, dtype: int32
# 0    0
# Name: name:Yves_Bissouma, dtype: int32
# 0    0
# Name: name:Zack_Steffen, dtype: int32
# 0    0
# Name: name:Zidane_Iqbal, dtype: int32
# 0    0
# Name: name:Çaglar_Söyüncü, dtype: int32
# 0    0
# Name: new_player, dtype: int32
# 0    True
# Name: player_available, dtype: bool
# 0
# 0    MID
# Name: position, dtype: object
# 0    0
# Name: position:DEF, dtype: int32
# 0    0
# Name: position:FWD, dtype: int32
# 0    0
# Name: position:GK, dtype: int32
# 0    1
# Name: position:MID, dtype: int32
# 0   NaN
# Name: red_cards, dtype: float64
# 0   NaN
# Name: red_cards_mean_upto_GW, dtype: float64
# 0   NaN
# Name: red_cards_rolling_3GW, dtype: float64
# 0   NaN
# Name: red_cards_rolling_5GW, dtype: float64
# 0    Southampton
# Name: team, dtype: object
# 0    0
# Name: team:Arsenal, dtype: int32
# 0    0
# Name: team:Aston Villa, dtype: int32
# 0    0
# Name: team:Bournemouth, dtype: int32
# 0    0
# Name: team:Brentford, dtype: int32
# 0    0
# Name: team:Brighton, dtype: int32
# 0    0
# Name: team:Chelsea, dtype: int32
# 0    0
# Name: team:Crystal Palace, dtype: int32
# 0    0
# Name: team:Everton, dtype: int32
# 0    0
# Name: team:Fulham, dtype: int32
# 0    0
# Name: team:Leeds, dtype: int32
# 0    0
# Name: team:Leicester, dtype: int32
# 0    0
# Name: team:Liverpool, dtype: int32
# 0    0
# Name: team:Man City, dtype: int32
# 0    0
# Name: team:Man Utd, dtype: int32
# 0    0
# Name: team:Newcastle, dtype: int32
# 0    0
# Name: team:Nott'm Forest, dtype: int32
# 0    1
# Name: team:Southampton, dtype: int32
# 0    0
# Name: team:Spurs, dtype: int32
# 0    0
# Name: team:West Ham, dtype: int32
# 0    0
# Name: team:Wolves, dtype: int32
# 0   NaN
# Name: value, dtype: float64
# 0   NaN
# Name: value_mean_upto_GW, dtype: float64
# 0   NaN
# Name: value_rolling_3GW, dtype: float64
# 0   NaN
# Name: value_rolling_5GW, dtype: float64
# 0   NaN
# Name: xP, dtype: float64
# 0   NaN
# Name: xP_mean_upto_GW, dtype: float64
# 0   NaN
# Name: xP_rolling_3GW, dtype: float64
# 0   NaN
# Name: xP_rolling_5GW, dtype: float64
# 0   NaN
# Name: yellow_cards, dtype: float64
# 0   NaN
# Name: yellow_cards_mean_upto_GW, dtype: float64
# 0   NaN
# Name: yellow_cards_rolling_3GW, dtype: float64
# 0   NaN
# Name: yellow_cards_rolling_5GW, dtype: float64

# %%
# Create Dict of Player attributes for start
# Convert the DataFrame to a list of dictionaries, one for each row
gw0_player_data_dict = gw0_player_data.to_dict(orient='records')

# Create a dictionary using the 'name' field as the key for each record
gw0_player_data_dict = {record['name']: record for record in gw0_player_data_dict}
gw0_player_data_dict


# %% -- Create Player Object
class Player:
    def __init__(self, **kwargs):
        self.points = 0
        for key, value in kwargs.items():
            setattr(self, key, value)

# Create list of Player Objects
all_available_players = []

for player in gw0_player_data_dict:
    player_to_add = Player(**gw0_player_data_dict[player])
    all_available_players.append(player_to_add)


class Team:
    def __init__(self):
        self.original_budget = 100_000_000
        self.dynamic_budget = self.original_budget # Budget that gets updated each game week as players value changes
        self.players = []
        self.team_points = 0

    def add_player(self, player):
        if player.value <= self.dynamic_budget:
            self.players.append(player)
            self.dynamic_budget -= player.value

    def remove_player(self, player):
        self.players.remove(player)
        self.dynamic_budget += player.value

    def update_team_points(self):
        self.team_points += sum(player.gw_points for player in self.players)

    def can_player_be_added_based_on_position(self, player):
        # Check the number of players of this position in the current team and compare with maximum allowed
        players_of_same_position = [p for p in self.players if p.position == player.position]
        return len(players_of_same_position) < MAX_POSITIONS[player.position]

# %% -- Helper Functions

# Function to prepare input for a single player
def prepare_input_for_player(player,gw):
    player_input = []
    
    # Normalise numeric features
    for feature in last_season_features + current_season_features:
        feature_to_add = (getattr(player, feature) - means_gw_player_data[gw]) / stds_gw_player_data[gw]
        player_input.append(feature_to_add)

    # Non-normalise numeric features
    for feature in ['new_player']:
        feature_to_add = getattr(player, feature)
        player_input.append(feature_to_add)

    # One-hot encoded character features
    for feature in ['position', 'team', 'gw']:
        one_hot_vector = one_hot_encoding_dicts[feature][getattr(player, feature)]
        player_input.extend(one_hot_vector)

    return player_input


# %% -- Setup NEAT structure

# Load NEAT config
config = neat.Config(neat.DefaultGenome, neat.DefaultReproduction,
                     neat.DefaultSpeciesSet, neat.DefaultStagnation,
                     'config.txt')

# Create the population
p = neat.Population(config)

# Add a stdout reporter to show progress in the terminal.
p.add_reporter(neat.StdOutReporter(True))
p.add_reporter(neat.StatisticsReporter())


def eval_genomes(genomes, config):
    for genome_id, genome in genomes:
        net = neat.nn.FeedForwardNetwork.create(genome, config)

        # Initialize fitness
        genome.fitness = 0
        
        # Create Team Object
        team = Team()

        # GAME WEEK 0 | INITIAL SELECTION
        output_dict = {}

        # Pass each Player Inputs to genome | Save Output in Dict
        for player in all_available_players:
            player_input = prepare_input_for_player(player,0)
            output = net.activate(player_input)
            output_dict[player.name] = output

        # Create a list of tuples (player, output) from the network output
        indexed_output = [(player, output_dict[player.name]) for player in all_available_players]

        # Sort the list by value in descending order
        indexed_output.sort(key=lambda x: x[1], reverse=True)

        # Keep track of the number of players added
        num_players_added = 0

        # Iterate over the sorted list, adding players to the team
        for player, _ in indexed_output:
            # Select player
            player = all_available_players[player]
            
            # Check if the player can be added based on position and budget
            if team.can_add_player_based_on_position(player) and team.dynamic_budget >= player.value:
                team.add_player(player)
                
                # Increment the number of players added
                num_players_added += 1
                
                # Stop if 11 players have been added
                if num_players_added == 11:
                    break

        # GAME WEEK 1+ | PLAY GAME
        # Loop through each Game Week
        for game_week in gw_values[1:]:
            # Update Player stats for Game Week
            for player in all_available_players:
                # Fetch the data for this player and this game week
                gw_data = data_22_23_gw_dict[game_week]
                player_data_for_gw = gw_data[gw_data['name'] == player.name]
                
                # If there is no data for this player for this game week, continue to the next player
                if player_data_for_gw.empty:
                    continue
                
                # Update player stats for this game week
                for stat in current_season_features:
                    setattr(player, stat, player_data_for_gw[stat].values[0])

                # Update Game Week 
                setattr(player, stat, game_week)



            # Update budget based on new player values
            team.dynamic_budget = sum(player.value for player in team.players) - team.original_budget


            output_dict = {}

            # Pass each Player Inputs to genome | Save Output in Dict
            for player in all_available_players:
                player_input = prepare_input_for_player(player,0)
                output = net.activate(player_input)
                output_dict[player.name] = output

            genome.fitness = team.team_points

# Run until a solution is found.
winner = p.run(eval_genomes, 50)
